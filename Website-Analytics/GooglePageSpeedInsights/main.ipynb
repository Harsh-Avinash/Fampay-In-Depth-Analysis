# %%
import requests
import csv
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px
from plotly.subplots import make_subplots

# %%
API_KEY = "AIzaSyDX_kJ-HB9cs0Z8KYDvzhENTDWw3oKTTdQ"
API_URL = "https://pagespeedonline.googleapis.com/pagespeedonline/v5/runPagespeed"
INPUT_FILE = "../../Website-Analytics/EveryTraceOfFampayPeriod/filtered_links.csv"
OUTPUT_FILE = "website_metrics.csv"

# %%
def read_urls_from_csv(file):
    with open(file, "r", newline="", encoding="utf-8") as csvfile:
        reader = csv.reader(csvfile)
        urls = set()
        for row in reader:
            urls.add(row[0])
        return list(urls)

def evaluate_website(url):
    params = {"url": url, "key": API_KEY}
    response = requests.get(API_URL, params=params)
    response_json = response.json()

    if "lighthouseResult" not in response_json:
        return None

    overall_score = response_json["lighthouseResult"]["categories"]["performance"]["score"]

    metrics = {
        "url": url,
        "overall_score": format(overall_score, ".8f"),
        "first_contentful_paint": response_json["lighthouseResult"]["audits"]["first-contentful-paint"]["numericValue"],
        "speed_index": response_json["lighthouseResult"]["audits"]["speed-index"]["numericValue"],
        "largest_contentful_paint": response_json["lighthouseResult"]["audits"]["largest-contentful-paint"]["numericValue"],
        "interactive": response_json["lighthouseResult"]["audits"]["interactive"]["numericValue"],
    }
    return metrics

def save_results_to_csv(result, file):
    with open(file, "a", newline="", encoding="utf-8") as csvfile:
        fieldnames = ["url", "overall_score", "first_contentful_paint", "speed_index", "largest_contentful_paint", "interactive"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        if csvfile.tell() == 0:
            writer.writeheader()

        writer.writerow(result)

def save_failed_urls_to_csv(failed_urls, file):
    with open(file, "a", newline="", encoding="utf-8") as csvfile:
        fieldnames = ["url", "error"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for failed_url in failed_urls:
            writer.writerow(failed_url)

# %%
urls = read_urls_from_csv(INPUT_FILE)
total_urls = len(urls)
failed_urls = []

for index, url in enumerate(urls):
    try:
        result = evaluate_website(url)
        if result:
            save_results_to_csv(result, OUTPUT_FILE)
            print(f"Progress: {index + 1}/{total_urls} - URL: {url} - Status: Success")
        else:
            error_message = "'lighthouseResult' not found"
            failed_urls.append({"url": url, "error": error_message})
            print(f"Progress: {index + 1}/{total_urls} - URL: {url} - Status: Failed - Error: {error_message}")
    except Exception as e:
        error_message = str(e)
        failed_urls.append({"url": url, "error": error_message})
        print(f"Progress: {index + 1}/{total_urls} - URL: {url} - Status: Failed - Error: {error_message}")
        save_failed_urls_to_csv(failed_urls, "failed_urls.csv")
# Out:
# Progress: 1/247 - URL: https://famapp.in/blog/looking-for-financial-independence-as-a-youngster-5-ways-to-earn-while-youre-young/ - Status: Success
# Progress: 2/247 - URL: https://fampay.in/blog/tag/parents/page/2/ - Status: Success
# Progress: 3/247 - URL: https://fampay.in/blog/author/aditi/ - Status: Success
# Progress: 4/247 - URL: https://fampay.in/blog/how-to-build-your-resume-and-portfolio-right-from-school/ - Status: Success
# Progress: 5/247 - URL: https://famapp.in/terms - Status: Success
# Progress: 6/247 - URL: https://famapp.in/blog/from-teenage-to-teen-entrepreneurs-make-your-story-inspiring/ - Status: Success
# Progress: 7/247 - URL: https://fampay.in/blog/the-most-beautiful-college-campuses-in-india/ - Status: Success
# Progress: 8/247 - URL: https://fampay.in/blog/how-i-blurred-age-barriers-with-technology/ - Status: Success
# Progress: 9/247 - URL: https://fampay.in/blog/tag/teens/ - Status: Success
# Progress: 10/247 - URL: https://fampay.in/blog/this-fintech-startup-by-iit-roorkee-alum-is-giving-teenagers-financial-freedom-responsibly-yourstory/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 11/247 - URL: https://fampay.in/blog/why-do-online-payments-get-stuck-and-what-can-you-do/ - Status: Success
# Progress: 12/247 - URL: https://fampay.in/blog/jumpstart-your-career-5-unconventional-career-choices-for-genzs/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 13/247 - URL: https://fampay.in/privacy - Status: Success
# Progress: 14/247 - URL: https://famapp.in/blog/famcard-your-first-prepaid-card/ - Status: Success
# Progress: 15/247 - URL: https://fampay.in/blog/tag/teens/page/2/ - Status: Success
# Progress: 16/247 - URL: https://fampay.in/blog/building-indias-first-genz-teen-exclusive-community/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 17/247 - URL: https://famapp.in/blog/teen-focused-fintech-startup-fampay-raises-38m-in-series-a/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 18/247 - URL: https://famapp.in/blog/things-you-must-know-as-a-teens-parent/ - Status: Success
# Progress: 19/247 - URL: https://famapp.in/blog/gen-z-gaming-how-to-make-real-money-by-playing-video-games/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 20/247 - URL: https://fampay.in/blog/a-marketers-guide-to-moment-marketing/ - Status: Success
# Progress: 21/247 - URL: https://fampay.in/blog/tag/teenpreneurs/ - Status: Success
# Progress: 22/247 - URL: https://famapp.in/blog/tag/famsays/page/2/ - Status: Success
# Progress: 23/247 - URL: https://fampay.in/blog/how-to-order-a-famcard-in-less-than-5-minutes/ - Status: Success
# Progress: 24/247 - URL: https://fampay.in/blog/club-teens-one-stop-online-community/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 25/247 - URL: https://fampay.in/blog/tag/lifestyle/ - Status: Success
# Progress: 26/247 - URL: https://fampay.in/blog/productivity-hacks-for-teens-this-will-change-your-life/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 27/247 - URL: https://fampay.in/blog/cyber-bullying-what-can-you-do-as-a-parent/ - Status: Success
# Progress: 28/247 - URL: https://famapp.in/blog/how-i-blurred-age-barriers-with-technology/ - Status: Success
# Progress: 29/247 - URL: https://fampay.in/blog/getting-your-generations-right-millennials-v-s-genz/ - Status: Success
# Progress: 30/247 - URL: https://fampay.in/blog/tag/famsays/ - Status: Success
# Progress: 31/247 - URL: https://famapp.in/blog/tag/growth/page/2/ - Status: Success
# Progress: 32/247 - URL: https://fampay.in/blog/tag/culture/ - Status: Success
# Progress: 33/247 - URL: https://famapp.in/blog/productivity-hacks-for-teens-this-will-change-your-life/ - Status: Success
# Progress: 34/247 - URL: https://famapp.in/blog/page/5/ - Status: Success
# Progress: 35/247 - URL: https://fampay.in/careers - Status: Success
# Progress: 36/247 - URL: https://fampay.in/blog/author/saipremtelkar/ - Status: Success
# Progress: 37/247 - URL: https://fampay.in/blog/tag/community/ - Status: Success
# Progress: 38/247 - URL: https://fampay.in/blog/fampays-guide-to-digital-payments-for-teens-important-dos-and-donts/ - Status: Success
# Progress: 39/247 - URL: https://fampay.in/blog/tag/tech/ - Status: Success
# Progress: 40/247 - URL: https://famapp.in/blog/a-marketers-guide-to-moment-marketing/ - Status: Success
# Progress: 41/247 - URL: https://famapp.in/blog/club-teens-one-stop-online-community/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 42/247 - URL: https://famapp.in/blog/4-ways-to-help-your-teen-learn-to-become-financially-responsible/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 43/247 - URL: https://fampay.in/press - Status: Success
# Progress: 44/247 - URL: https://famapp.in/blog/tag/parents/page/2/ - Status: Success
# Progress: 45/247 - URL: https://famapp.in/blog/getting-your-generations-right-millennials-v-s-genz/ - Status: Success
# Progress: 46/247 - URL: https://fampay.in/blog/remote-working-divided-by-distance-united-by-mission/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 47/247 - URL: https://famapp.in/blog/13-boredom-busters-for-teens/ - Status: Success
# Progress: 48/247 - URL: https://fampay.in/faqs - Status: Success
# Progress: 49/247 - URL: https://famapp.in/blog/writing-content-for-a-content-saturated-generation/ - Status: Success
# Progress: 50/247 - URL: https://famapp.in/blog/how-to-go-from-awkward-to-awesome-in-your-teens/ - Status: Success
# Progress: 51/247 - URL: https://famapp.in/blog/living-life-genz-style/ - Status: Success
# Progress: 52/247 - URL: https://fampay.in/blog/impact-of-social-distancing-on-teen-mental-health/ - Status: Success
# Progress: 53/247 - URL: https://famapp.in/blog/how-a-pressing-problem-can-lead-to-technological-innovation/ - Status: Success
# Progress: 54/247 - URL: https://famapp.in/blog/tag/news/ - Status: Success
# Progress: 55/247 - URL: https://fampay.in/ - Status: Success
# Progress: 56/247 - URL: https://famapp.in/blog/tag/lifestyle/page/2/ - Status: Success
# Progress: 57/247 - URL: https://famapp.in/blog/why-vaccination-a-guide-to-vaccination-for-teens-in-india/ - Status: Success
# Progress: 58/247 - URL: https://famapp.in/faqs - Status: Success
# Progress: 59/247 - URL: https://fampay.in/blog/tag/news/ - Status: Success
# Progress: 60/247 - URL: https://famapp.in/blog/top-5-tips-to-communicate-better-with-your-teenager/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 61/247 - URL: https://famapp.in/blog/365-days-of-internship-at-fampay/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 62/247 - URL: https://famapp.in/blog/this-fintech-startup-by-iit-roorkee-alum-is-giving-teenagers-financial-freedom-responsibly-yourstory/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 63/247 - URL: https://famapp.in/blog/journey-to-the-centre-of-100k-downloads/ - Status: Success
# Progress: 64/247 - URL: https://famapp.in/blog/savings-for-teens-its-never-too-early-to-start/ - Status: Success
# Progress: 65/247 - URL: https://famapp.in/blog/everything-you-need-to-know-about-our-numberless-card/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 66/247 - URL: https://fampay.in/blog/being-a-digital-parent-tips-to-mentor-everything-digital-that-your-teen-uses/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 67/247 - URL: https://famapp.in/blog/pocket-money-for-teenagers-why-it-matters/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 68/247 - URL: https://fampay.in/blog/author/hrishikesh/ - Status: Success
# Progress: 69/247 - URL: https://famapp.in/blog/tag/pr-news/ - Status: Success
# Progress: 70/247 - URL: https://famapp.in/about - Status: Success
# Progress: 71/247 - URL: https://famapp.in/blog/12-queer-led-small-businesses-you-need-to-support-this-pride-month/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 72/247 - URL: https://famapp.in/blog/tag/parents/ - Status: Success
# Progress: 73/247 - URL: https://fampay.in/blog/tag/product/page/2/ - Status: Success
# Progress: 74/247 - URL: https://fampay.in/blog/how-to-save-those-extra-bucks-while-shopping/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 75/247 - URL: https://fampay.in/blog/perks-of-using-the-famcard-me/ - Status: Success
# Progress: 76/247 - URL: https://famapp.in/blog/the-story-behind-fampays-tech-stack/ - Status: Success
# Progress: 77/247 - URL: https://famapp.in/blog/building-indias-first-genz-teen-exclusive-community/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 78/247 - URL: https://famapp.in/blog/teen-fashion-trends-that-we-love/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 79/247 - URL: https://fampay.in/blog/fampay-announces-launch-of-indias-first-numberless-card/ - Status: Success
# Progress: 80/247 - URL: https://fampay.in/blog/how-can-teens-open-shops-on-instagram/ - Status: Success
# Progress: 81/247 - URL: https://famapp.in/blog/fampay-the-solution-to-your-cash-problems/ - Status: Success
# Progress: 82/247 - URL: https://fampay.in/blog/author/ayushi/ - Status: Success
# Progress: 83/247 - URL: https://fampay.in/blog/teen-fashion-trends-that-we-love/ - Status: Success
# Progress: 84/247 - URL: https://famapp.in/partner - Status: Success
# Progress: 85/247 - URL: https://famapp.in/blog/study-habits-that-are-simple-and-highly-effective/ - Status: Success
# Progress: 86/247 - URL: https://famapp.in/blog/zetas-fusion-to-power-fampays-cashless-payments-for-gen-z/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 87/247 - URL: https://fampay.in/blog/365-days-of-internship-at-fampay/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 88/247 - URL: https://fampay.in/blog/researching-the-unresearched-genzs/ - Status: Success
# Progress: 89/247 - URL: https://fampay.in/blog/when-building-for-genzs-build-it-on-discord/ - Status: Success
# Progress: 90/247 - URL: https://famapp.in/blog/remote-working-divided-by-distance-united-by-mission/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 91/247 - URL: https://famapp.in/blog/social-commerce-making-money-just-through-social-media/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 92/247 - URL: https://famapp.in/blog/why-do-online-payments-get-stuck-and-what-can-you-do/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 93/247 - URL: https://fampay.in/blog - Status: Success
# Progress: 94/247 - URL: https://famapp.in/blog/one-stop-solution-for-all-your-kyc-concerns/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 95/247 - URL: https://famapp.in/blog/how-to-clean-up-your-android-apps-dependencies-the-ultimate-guide-2/ - Status: Success
# Progress: 96/247 - URL: https://famapp.in/blog/config-variables-changing-system-behaviour-live-in-production/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 97/247 - URL: https://fampay.in/blog/famcard-your-first-debit-card/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 98/247 - URL: https://fampay.in/blog/covid-19-vaccination-as-a-teen-a-guide/ - Status: Success
# Progress: 99/247 - URL: https://famapp.in/blog/7-cool-insta-dads-of-bollywood/ - Status: Success
# Progress: 100/247 - URL: https://fampay.in/blog/what-are-the-perks-of-using-fampay/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 101/247 - URL: https://fampay.in/blog/how-a-pressing-problem-can-lead-to-technological-innovation/ - Status: Success
# Progress: 102/247 - URL: https://famapp.in/blog/perks-of-using-the-famcard-me/ - Status: Success
# Progress: 103/247 - URL: https://fampay.in/blog/one-stop-solution-for-all-your-kyc-concerns/ - Status: Success
# Progress: 104/247 - URL: https://famapp.in/blog/tag/tech/ - Status: Success
# Progress: 105/247 - URL: https://fampay.in/blog/effectively-harnessing-motion-design-for-genzs/ - Status: Success
# Progress: 106/247 - URL: https://famapp.in/blog/how-instagram-reel-can-really-grow-your-brand/ - Status: Success
# Progress: 107/247 - URL: https://famapp.in/blog/when-building-for-genzs-build-it-on-discord/ - Status: Success
# Progress: 108/247 - URL: https://famapp.in/blog/effectively-harnessing-motion-design-for-genzs/ - Status: Success
# Progress: 109/247 - URL: https://famapp.in/blog/3-financial-lessons-from-nature-itself/ - Status: Success
# Progress: 110/247 - URL: https://famapp.in/blog/tag/lifestyle/page/3/ - Status: Success
# Progress: 111/247 - URL: https://famapp.in/blog/decor-ideas-that-would-transform-your-room-at-home-or-hostel/ - Status: Success
# Progress: 112/247 - URL: https://famapp.in/blog/genz-commits-to-fight-covid-19/ - Status: Success
# Progress: 113/247 - URL: https://famapp.in/blog/bridging-generation-gap-understanding-your-genz-teenager-better/ - Status: Success
# Progress: 114/247 - URL: https://famapp.in/blog/tag/lifestyle/ - Status: Success
# Progress: 115/247 - URL: https://famapp.in/blog/want-to-become-a-teenage-influencer-start-here/ - Status: Success
# Progress: 116/247 - URL: https://famapp.in/blog/fampay-is-set-to-launch-indias-first-and-biggest-digi-fest-for-teens/ - Status: Success
# Progress: 117/247 - URL: https://fampay.in/blog/healthy-wealth-how-can-parents-have-a-healthy-discussion-about-money-with-their-children/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 118/247 - URL: https://famapp.in/blog/impact-of-social-distancing-on-teen-mental-health/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 119/247 - URL: https://fampay.in/blog/a-practical-guide-to-app-store-optimization/ - Status: Success
# Progress: 120/247 - URL: https://famapp.in/blog - Status: Success
# Progress: 121/247 - URL: https://famapp.in/blog/tag/culture/ - Status: Success
# Progress: 122/247 - URL: https://fampay.in/blog/page/3/ - Status: Success
# Progress: 123/247 - URL: https://famapp.in/blog/tag/growth/ - Status: Success
# Progress: 124/247 - URL: https://fampay.in/blog/how-instagram-reel-can-really-grow-your-brand/ - Status: Success
# Progress: 125/247 - URL: https://famapp.in/privacy - Status: Success
# Progress: 126/247 - URL: https://fampay.in/blog/author/kaavyya/ - Status: Success
# Progress: 127/247 - URL: https://famapp.in/blog/how-to-save-those-extra-bucks-while-shopping/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 128/247 - URL: https://fampay.in/blog/study-habits-that-are-simple-and-highly-effective/ - Status: Success
# Progress: 129/247 - URL: https://famapp.in/blog/page/4/ - Status: Success
# Progress: 130/247 - URL: https://famapp.in/blog/fampay-partners-with-visa-to-launch-indias-first-doodle-card-for-genz/ - Status: Success
# Progress: 131/247 - URL: https://fampay.in/blog/12-queer-led-small-businesses-you-need-to-support-this-pride-month/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 132/247 - URL: https://fampay.in/blog/discover-fampays-engagement-service-missions-3/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 133/247 - URL: https://fampay.in/blog/zetas-fusion-to-power-fampays-cashless-payments-for-gen-z/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 134/247 - URL: Link - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 135/247 - URL: https://fampay.in/blog/pocket-money-for-teenagers-why-it-matters/ - Status: Success
# Progress: 136/247 - URL: https://fampay.in/blog/how-to-clean-up-your-android-apps-dependencies-the-ultimate-guide-2/ - Status: Success
# Progress: 137/247 - URL: https://fampay.in/blog/every-little-thing-counts-ways-in-which-you-can-contribute-to-society-as-a-teenager/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 138/247 - URL: https://famapp.in/blog/ - Status: Success
# Progress: 139/247 - URL: https://famapp.in/ - Status: Success
# Progress: 140/247 - URL: https://fampay.in/blog/genz-commits-to-fight-covid-19/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 141/247 - URL: https://fampay.in/blog/ - Status: Success
# Progress: 142/247 - URL: https://fampay.in/blog/life-of-an-intern-is-love/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 143/247 - URL: https://fampay.in/blog/author/ritwick/ - Status: Success
# Progress: 144/247 - URL: https://famapp.in/press - Status: Success
# Progress: 145/247 - URL: https://famapp.in/blog/how-to-grow-your-instagram-followers-a-quick-guide-for-all-genz-brands/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 146/247 - URL: https://fampay.in/blog/fampay-is-set-to-launch-indias-first-and-biggest-digi-fest-for-teens/ - Status: Success
# Progress: 147/247 - URL: https://fampay.in/blog/the-story-behind-fampays-tech-stack/ - Status: Success
# Progress: 148/247 - URL: https://famapp.in/blog/fampay-raises-4-7m-from-y-combinator-sequoia-venture-highway-others/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 149/247 - URL: https://famapp.in/blog/fampay-amongst-linkedins-top-startups-list-2021/ - Status: Success
# Progress: 150/247 - URL: https://famapp.in/blog/5-habits-of-highly-successful-teens/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 151/247 - URL: https://fampay.in/blog/a-to-z-of-teenage-finance-financial-terms-every-parent-should-teach-their-teens/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 152/247 - URL: https://fampay.in/blog/page/2/ - Status: Success
# Progress: 153/247 - URL: https://fampay.in/terms - Status: Success
# Progress: 154/247 - URL: https://famapp.in/blog/famstars-we-stress-less-and-accomplish-more/ - Status: Success
# Progress: 155/247 - URL: https://famapp.in/blog/tag/product/ - Status: Success
# Progress: 156/247 - URL: https://famapp.in/blog/what-makes-fampay-secure/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 157/247 - URL: https://famcard.me/ - Status: Success
# Progress: 158/247 - URL: https://famapp.in/blog/digital-payments-exploding-in-india-yet-the-tech-savvy-teens-still-stuck-paying-with-cash-survey-by-fampay-indias-first-neobank-for-teenagers/ - Status: Success
# Progress: 159/247 - URL: https://famapp.in/blog/page/3/ - Status: Success
# Progress: 160/247 - URL: https://famapp.in/contact - Status: Success
# Progress: 161/247 - URL: https://fampay.in/blog/author/sajal/ - Status: Success
# Progress: 162/247 - URL: https://famapp.in/blog/evolution-of-parenting-parent-of-a-millennial-vs-parent-of-a-genz-kid/ - Status: Success
# Progress: 163/247 - URL: https://famapp.in/careers - Status: Success
# Progress: 164/247 - URL: https://famapp.in/blog/what-are-the-perks-of-using-fampay/ - Status: Success
# Progress: 165/247 - URL: https://famapp.in/blog/being-a-digital-parent-tips-to-mentor-everything-digital-that-your-teen-uses/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 166/247 - URL: https://fampay.in/blog/7-clever-saving-hacks-for-teenagers-this-will-save-you-a-fortune/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 167/247 - URL: https://fampay.in/blog/tag/lifestyle/page/2/ - Status: Success
# Progress: 168/247 - URL: https://famapp.in/blog/baddie-on-a-budget-budgeting-tricks-for-teens/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 169/247 - URL: https://fampay.in/blog/4-ways-to-help-your-teen-learn-to-become-financially-responsible/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 170/247 - URL: https://famapp.in/blog/top-5-platforms-for-students-to-learn-new-things/ - Status: Success
# Progress: 171/247 - URL: https://famapp.in/blog/healthy-wealth-how-can-parents-have-a-healthy-discussion-about-money-with-their-children/ - Status: Success
# Progress: 172/247 - URL: https://fampay.in/blog/things-you-must-know-as-a-teens-parent/ - Status: Success
# Progress: 173/247 - URL: https://fampay.in/blog/author/fampay/ - Status: Success
# Progress: 174/247 - URL: https://fampay.in/about - Status: Success
# Progress: 175/247 - URL: https://famapp.in/blog/a-to-z-of-teenage-finance-financial-terms-every-parent-should-teach-their-teens/ - Status: Success
# Progress: 176/247 - URL: https://famapp.in/blog/tag/community/ - Status: Success
# Progress: 177/247 - URL: https://fampay.in/blog/social-commerce-making-money-just-through-social-media/ - Status: Success
# Progress: 178/247 - URL: https://famapp.in/blog/fampay-announces-launch-of-indias-first-numberless-card/ - Status: Success
# Progress: 179/247 - URL: https://fampay.in/blog/author/sameeran/ - Status: Success
# Progress: 180/247 - URL: https://famapp.in/blog/life-of-an-intern-is-love/ - Status: Success
# Progress: 181/247 - URL: https://fampay.in/blog/tag/pr-news/ - Status: Success
# Progress: 182/247 - URL: https://fampay.in/blog/savings-for-teens-its-never-too-early-to-start/ - Status: Success
# Progress: 183/247 - URL: https://famapp.in/blog/discover-fampays-engagement-service-missions-3/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 184/247 - URL: https://famapp.in/blog/researching-the-unresearched-genzs/ - Status: Success
# Progress: 185/247 - URL: https://fampay.in/blog/implementing-an-in-memory-queue/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 186/247 - URL: https://famapp.in/blog/the-most-beautiful-college-campuses-in-india/ - Status: Success
# Progress: 187/247 - URL: https://fampay.in/blog/author/diya/ - Status: Success
# Progress: 188/247 - URL: https://famapp.in/blog/how-to-order-a-famcard-in-less-than-5-minutes/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 189/247 - URL: https://fampay.in/blog/author/arohi/ - Status: Success
# Progress: 190/247 - URL: https://fampay.in/blog/author/priyanka/ - Status: Success
# Progress: 191/247 - URL: https://fampay.in/blog/3-financial-lessons-from-nature-itself/ - Status: Success
# Progress: 192/247 - URL: https://fampay.in/blog/fampay-amongst-linkedins-top-startups-list-2021/ - Status: Success
# Progress: 193/247 - URL: https://fampay.in/blog/author/fampay/page/2/ - Status: Success
# Progress: 194/247 - URL: https://fampay.in/blog/evolution-of-parenting-parent-of-a-millennial-vs-parent-of-a-genz-kid/ - Status: Success
# Progress: 195/247 - URL: https://fampay.in/blog/guide-for-seeking-support-from-fampay-important-dos-and-donts/ - Status: Success
# Progress: 196/247 - URL: https://famapp.in/blog/a-practical-guide-to-app-store-optimization/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 197/247 - URL: https://fampay.in/blog/living-life-genz-style/ - Status: Success
# Progress: 198/247 - URL: https://fampay.in/blog/baddie-on-a-budget-budgeting-tricks-for-teens/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 199/247 - URL: https://fampay.in/blog/how-to-grow-your-instagram-followers-a-quick-guide-for-all-genz-brands/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 200/247 - URL: https://fampay.in/blog/what-makes-fampay-secure/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 201/247 - URL: https://famapp.in/blog/fampays-guide-to-digital-payments-for-teens-important-dos-and-donts/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 202/247 - URL: https://famapp.in/blog/covid-19-vaccination-as-a-teen-a-guide/ - Status: Success
# Progress: 203/247 - URL: https://fampay.in/blog/top-5-tips-to-communicate-better-with-your-teenager/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 204/247 - URL: https://fampay.in/blog/author/aadithyan/ - Status: Success
# Progress: 205/247 - URL: https://fampay.in/blog/config-variables-changing-system-behaviour-live-in-production/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 206/247 - URL: https://famapp.in/blog/how-to-build-your-resume-and-portfolio-right-from-school/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 207/247 - URL: https://famapp.in/blog/guide-for-seeking-support-from-fampay-important-dos-and-donts/ - Status: Success
# Progress: 208/247 - URL: https://fampay.in/blog/tag/product/ - Status: Success
# Progress: 209/247 - URL: https://famapp.in/blog/implementing-an-in-memory-queue/ - Status: Success
# Progress: 210/247 - URL: https://fampay.in/blog/digital-payments-exploding-in-india-yet-the-tech-savvy-teens-still-stuck-paying-with-cash-survey-by-fampay-indias-first-neobank-for-teenagers/ - Status: Success
# Progress: 211/247 - URL: https://famapp.in/blog/7-clever-saving-hacks-for-teenagers-this-will-save-you-a-fortune/ - Status: Success
# Progress: 212/247 - URL: https://fampay.in/blog/author/shiv/ - Status: Success
# Progress: 213/247 - URL: https://fampay.in/blog/author/tanya/ - Status: Success
# Progress: 214/247 - URL: https://fampay.in/blog/tag/parents/ - Status: Success
# Progress: 215/247 - URL: https://famapp.in/blog/mental-health-matters-5-things-to-remember-while-in-quarantine/ - Status: Success
# Progress: 216/247 - URL: https://famapp.in/blog/cyber-bullying-what-can-you-do-as-a-parent/ - Status: Success
# Progress: 217/247 - URL: https://fampay.in/blog/tag/growth/page/2/ - Status: Success
# Progress: 218/247 - URL: https://fampay.in/contact - Status: Success
# Progress: 219/247 - URL: https://fampay.in/blog/author/suhani/ - Status: Success
# Progress: 220/247 - URL: https://fampay.in/blog/13-boredom-busters-for-teens/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 221/247 - URL: https://fampay.in/blog/tag/growth/ - Status: Success
# Progress: 222/247 - URL: https://fampay.in/partner - Status: Success
# Progress: 223/247 - URL: https://fampay.in/blog/author/shifa/ - Status: Success
# Progress: 224/247 - URL: https://fampay.in/blog/author/tiara/ - Status: Success
# Progress: 225/247 - URL: https://fampay.in/blog/fampay-partners-with-visa-to-launch-indias-first-doodle-card-for-genz/ - Status: Success
# Progress: 226/247 - URL: https://famapp.in/blog/tag/famsays/ - Status: Success
# Progress: 227/247 - URL: https://famapp.in/blog/teen-bucket-list-10-things-you-must-to-do-in-your-teens/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 228/247 - URL: https://fampay.in/blog/famstars-we-stress-less-and-accomplish-more/ - Status: Success
# Progress: 229/247 - URL: https://famapp.in/blog/curious-about-famcard-heres-everything-to-know/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 230/247 - URL: https://fampay.in/blog/everything-you-need-to-know-about-our-numberless-card/ - Status: Success
# Progress: 231/247 - URL: https://fampay.in/blog/curious-about-famcard-heres-everything-to-know/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 232/247 - URL: https://fampay.in/blog/fampay-raises-4-7m-from-y-combinator-sequoia-venture-highway-others/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 233/247 - URL: https://famapp.in/blog/how-can-teens-open-shops-on-instagram/ - Status: Success
# Progress: 234/247 - URL: https://fampay.in/blog/teen-focused-fintech-startup-fampay-raises-38m-in-series-a/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__
# Progress: 235/247 - URL: https://fampay.in/blog/author/charvi/ - Status: Success
# Progress: 236/247 - URL: https://famapp.in/blog/every-little-thing-counts-ways-in-which-you-can-contribute-to-society-as-a-teenager/ - Status: Failed - Error: 'lighthouseResult' not found
# Progress: 237/247 - URL: https://fampay.in/blog/fampay-the-solution-to-your-cash-problems/ - Status: Success
# Progress: 238/247 - URL: https://famapp.in/blog/tag/product/page/2/ - Status: Success
# Progress: 239/247 - URL: https://famapp.in/blog/page/2/ - Status: Success
# Progress: 240/247 - URL: https://famapp.in/blog/top-4-head-turning-fashion-tips-and-trends-for-the-sassy-gen-z/ - Status: Success
# Progress: 241/247 - URL: https://famapp.in/blog/tag/famsays/page/3/ - Status: Success
# Progress: 242/247 - URL: https://fampay.in/blog/decor-ideas-that-would-transform-your-room-at-home-or-hostel/ - Status: Success
# Progress: 243/247 - URL: https://fampay.in/blog/writing-content-for-a-content-saturated-generation/ - Status: Success
# Progress: 244/247 - URL: https://fampay.in/blog/author/garvita/ - Status: Success
# Progress: 245/247 - URL: https://fampay.in/blog/why-vaccination-a-guide-to-vaccination-for-teens-in-india/ - Status: Success
# Progress: 246/247 - URL: https://fampay.in/blog/tag/famsays/page/2/ - Status: Success
# Progress: 247/247 - URL: https://famapp.in/blog/jumpstart-your-career-5-unconventional-career-choices-for-genzs/ - Status: Failed - Error: unsupported format string passed to NoneType.__format__

# %%
data = pd.read_csv('website_metrics.csv')

# %%
fig1 = go.Figure()

fig1.add_trace(
    go.Scatter(
        x=data["url"], 
        y=data["overall_score"],
        mode='markers',
        marker=dict(
            size=15,
            color=data["overall_score"], 
            colorscale='Viridis', 
            showscale=True
        ),
        text=data["url"],
    )
)

fig1.update_layout(title='Overall Score', xaxis_title='URL', yaxis_title='Score', hovermode='closest')

pio.write_html(fig1, "../../fam-report-site/public/Web-Analytics/overall_score.html")
fig1.show()

# %%
data['size'] = data['largest_contentful_paint'] / 100

fig = go.Figure(data=go.Scatter(
    x=data['overall_score'],
    y=data['first_contentful_paint'],
    mode='markers',
    marker=dict(
        size=data['size'],
        sizemode='area',
        sizeref=0.01,
        sizemin=4
    ),
    text=data['url'],
))

fig.update_layout(
    title='Overall Score vs First Contentful Paint (Size: Largest Contentful Paint)',
    xaxis=dict(
        title='Overall Score',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    yaxis=dict(
        title='First Contentful Paint',
        gridcolor='white',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
)

# Save plot
plot_filename = "../../fam-report-site/public/Web-Analytics/bubble_chart.html"
pio.write_html(fig, plot_filename)
fig.show()

# %%
fig = go.Figure(data=[go.Scatter3d(
    x=data['overall_score'],
    y=data['first_contentful_paint'],
    z=data['interactive'],
    mode='markers',
    marker=dict(
        size=data['largest_contentful_paint'] / 100,
        sizemode='area',
        sizeref=0.01,
        sizemin=4,
        color=data['speed_index'], 
        colorscale='Viridis', 
        colorbar=dict(title="Speed Index"),
        opacity=0.8
    ),
    text=data['url'],
)])

fig.update_layout(
    title='3D Scatter Plot: Overall Score, First Contentful Paint, Interactive, Largest Contentful Paint and Speed Index',
    scene=dict(
        xaxis=dict(title='Overall Score'),
        yaxis=dict(title='First Contentful Paint'),
        zaxis=dict(title='Interactive'),
    ),
    autosize=False,
    width=800,
    height=800,
)

# Save plot
plot_filename = "../../fam-report-site/public/Web-Analytics/3d_scatter_plot.html"
pio.write_html(fig, plot_filename)
fig.show()

# %%
fig = px.treemap(data, path=['url'], values='overall_score',
                 color='overall_score', hover_data=['overall_score'],
                 color_continuous_scale='RdBu', title='Overall Score Treemap')

fig.write_html("../../fam-report-site/public/Web-Analytics/overall_score_treemap.html")
fig.show()

# %%
# Convert overall_score to numeric as it was saved in the csv as a string with decimal precision
data['overall_score'] = pd.to_numeric(data['overall_score'])

fig = px.scatter_matrix(data,
    dimensions=["overall_score", "first_contentful_paint", "speed_index", "largest_contentful_paint", "interactive"],
    title="Website Metrics Scatterplot Matrix")
fig.update_traces(diagonal_visible=False)  # Hide diagonal distribution plots
fig.write_html("../../fam-report-site/public/Web-Analytics/scatterplot_matrix.html")
fig.show()
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.

# %%
color_scale = px.colors.diverging.Tealrose  # choose any available color scale

# Specify only numeric columns
numeric_cols = ["overall_score", "first_contentful_paint", "speed_index", "largest_contentful_paint", "interactive"]

# Normalize your data for better visualization, especially if the metrics are on different scales
data_normalized = (data[numeric_cols] - data[numeric_cols].min()) / (data[numeric_cols].max() - data[numeric_cols].min())

# Append the 'url' column from the original dataframe
data_normalized['url'] = data['url']

# Append the 'url' column from the original dataframe
data_normalized['url'] = data['url']

fig = px.parallel_coordinates(
    data_normalized, 
    color=data_normalized["overall_score"] * 100,  # or any other variable of interest
    labels={
        "url": "URL",
        "overall_score": "Overall Score",
        "first_contentful_paint": "First Contentful Paint",
        "speed_index": "Speed Index",
        "largest_contentful_paint": "Largest Contentful Paint",
        "interactive": "Interactive"
    },
    color_continuous_scale=color_scale,
    color_continuous_midpoint=0.5  # This can be changed to adjust the color scale midpoint
)

# Modify the layout
fig.update_layout(
    title='Parallel Coordinates Plot of Website Metrics',
    autosize=False,
    width=800,
    height=500
)

# Save the plot
pio.write_html(fig, "../../fam-report-site/public/Web-Analytics/parallel_coordinates.html")
fig.show()
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
