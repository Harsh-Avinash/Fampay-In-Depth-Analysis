# %%
import csv
import instaloader

# %%
# Replace 'YOUR_USERNAME' and 'YOUR_PASSWORD' with your Instagram login credentials
username = 'HA_Scrapper'
password = 'Disturbuteablepassword'

# Initialize Instaloader
L = instaloader.Instaloader()

# Login to Instagram
L.context.username = username
L.context.password = password
L.login(username, password)

# Load the FamPay Instagram profile
profile = instaloader.Profile.from_username(L.context, 'fam.india')

# %%
# Extract the content of the posts
posts_data = []
count = 0
for post in profile.get_posts():
    print("Extracting data from post: " + post.shortcode)
    post_data = {
        'shortcode': post.shortcode,
        'caption': post.caption,
        'upload_time': post.date_local,
        'num_likes': post.likes,
        'num_comments': post.comments,
        'is_video': post.is_video,
        'video_views': post.video_view_count if post.is_video else None,
        'url': post.url
    }
    print("Extracted data from post: " + post.shortcode)
    count += 1
    posts_data.append(post_data)
# Out:
# Extracting data from post: CsTlx1SgF4t
# Extracted data from post: CsTlx1SgF4t
# Extracting data from post: CsOIQgFyTdV
# Extracted data from post: CsOIQgFyTdV
# Extracting data from post: CsMIyO7pnub
# Extracted data from post: CsMIyO7pnub
# Extracting data from post: CsLx3gMJAuC
# Extracted data from post: CsLx3gMJAuC
# Extracting data from post: Cr5yP-wJ3Mn
# Extracted data from post: Cr5yP-wJ3Mn
# Extracting data from post: Cr3cB2HpcB9
# Extracted data from post: Cr3cB2HpcB9
# Extracting data from post: Cr07LRzpjJB
# Extracted data from post: Cr07LRzpjJB
# Extracting data from post: CrvgPeppPuJ
# Extracted data from post: CrvgPeppPuJ
# Extracting data from post: CrtD1L6gVSt
# Extracted data from post: CrtD1L6gVSt
# Extracting data from post: Crn4uvcpL6q
# Extracted data from post: Crn4uvcpL6q
# Extracting data from post: CrlbvIzAccT
# Extracted data from post: CrlbvIzAccT
# Extracting data from post: CrlEQ2gpB9c
# Extracted data from post: CrlEQ2gpB9c
# Extracting data from post: Crga0u0APGz
# Extracted data from post: Crga0u0APGz
# Extracting data from post: CrduTV9Jw-5
# Extracted data from post: CrduTV9Jw-5
# Extracting data from post: CrdHH2Zpn5R
# Extracted data from post: CrdHH2Zpn5R
# Extracting data from post: CrXogaGgxAL
# Extracted data from post: CrXogaGgxAL
# Extracting data from post: CrV2kOLgqq8
# Extracted data from post: CrV2kOLgqq8
# Extracting data from post: CrTd6o7prTN
# Extracted data from post: CrTd6o7prTN
# Extracting data from post: CrQ3Dx1pMTB
# Extracted data from post: CrQ3Dx1pMTB
# Extracting data from post: CrOMKLLJG5L
# Extracted data from post: CrOMKLLJG5L
# Extracting data from post: CrI_4o2phRg
# Extracted data from post: CrI_4o2phRg
# Extracting data from post: CrEBhhjpJBD
# Extracted data from post: CrEBhhjpJBD
# Extracting data from post: Cq-wlvUpCIC
# Extracted data from post: Cq-wlvUpCIC
# Extracting data from post: Cq8MICtJmz_
# Extracted data from post: Cq8MICtJmz_
# Extracting data from post: Cq0fCzaJzPN
# Extracted data from post: Cq0fCzaJzPN
# Extracting data from post: Cqsp0vhpHgc
# Extracted data from post: Cqsp0vhpHgc
# Extracting data from post: Cqp_XT-JQfQ
# Extracted data from post: Cqp_XT-JQfQ
# Extracting data from post: Cqna59Kppti
# Extracted data from post: Cqna59Kppti
# Extracting data from post: CqlAroZpQqL
# Extracted data from post: CqlAroZpQqL
# Extracting data from post: CqiS0jvpGUa
# Extracted data from post: CqiS0jvpGUa
# Extracting data from post: CqdFed2Jczc
# Extracted data from post: CqdFed2Jczc
# Extracting data from post: CqazdxKJCdu
# Extracted data from post: CqazdxKJCdu
# Extracting data from post: CqX_p0lDtOw
# Extracted data from post: CqX_p0lDtOw
# Extracting data from post: CqS6lTzDOU_
# Extracted data from post: CqS6lTzDOU_
# Extracting data from post: CqNxGb_JqNh
# Extracted data from post: CqNxGb_JqNh
# Extracting data from post: CqIrZbnpFFX
# Extracted data from post: CqIrZbnpFFX
# Extracting data from post: CqDdvvxpz3r
# Extracted data from post: CqDdvvxpz3r
# Extracting data from post: CqAzQ0JJlVL
# Extracted data from post: CqAzQ0JJlVL
# Extracting data from post: Cp7zuJUJ10o
# Extracted data from post: Cp7zuJUJ10o
# Extracting data from post: Cp2txMyppm-
# Extracted data from post: Cp2txMyppm-
# Extracting data from post: CpxhkhTp7oc
# Extracted data from post: CpxhkhTp7oc
# Extracting data from post: CpvCwotpVTM
# Extracted data from post: CpvCwotpVTM
# Extracting data from post: CppyqFOJBST
# Extracted data from post: CppyqFOJBST
# Extracting data from post: CpkrfqWJ8fs
# Extracted data from post: CpkrfqWJ8fs
# Extracting data from post: CpXpF3pJGB_
# Extracted data from post: CpXpF3pJGB_
# Extracting data from post: CpVJlKCpz9O
# Extracted data from post: CpVJlKCpz9O
# Extracting data from post: CpNey_7AUtp
# Extracted data from post: CpNey_7AUtp
# Extracting data from post: CpFt5-TpBtj
# Extracted data from post: CpFt5-TpBtj
# Extracting data from post: CpDS0smJTLQ
# Extracted data from post: CpDS0smJTLQ
# Extracting data from post: CpA5iT1yBsB
# Extracted data from post: CpA5iT1yBsB
# Extracting data from post: Co96kh2Ji9D
# Extracted data from post: Co96kh2Ji9D
# Extracting data from post: Co7O_U7p8ld
# Extracted data from post: Co7O_U7p8ld
# Extracting data from post: Co4yzWaJIOH
# Extracted data from post: Co4yzWaJIOH
# Extracting data from post: Co2R9LKJMYf
# Extracted data from post: Co2R9LKJMYf
# Extracting data from post: Coz1p4aJGnd
# Extracted data from post: Coz1p4aJGnd
# Extracting data from post: CoxIFOnJSbC
# Extracted data from post: CoxIFOnJSbC
# Extracting data from post: CounSa6ArjL
# Extracted data from post: CounSa6ArjL
# Extracting data from post: Cor4tutpdIm
# Extracted data from post: Cor4tutpdIm
# Extracting data from post: CopN45aJzLd
# Extracted data from post: CopN45aJzLd
# Extracting data from post: ComzpO3pF3R
# Extracted data from post: ComzpO3pF3R
# Extracting data from post: CokBi5Hpqwx
# Extracted data from post: CokBi5Hpqwx
# Extracting data from post: Cohr_piJLj7
# Extracted data from post: Cohr_piJLj7
# Extracting data from post: CocVTlHJbVX
# Extracted data from post: CocVTlHJbVX
# Extracting data from post: CoZ_1vsJJzr
# Extracted data from post: CoZ_1vsJJzr
# Extracting data from post: CoXYn5MJStK
# Extracted data from post: CoXYn5MJStK
# Extracting data from post: CoU1ezXp6Vl
# Extracted data from post: CoU1ezXp6Vl
# Extracting data from post: CoSR9j8AR5Z
# Extracted data from post: CoSR9j8AR5Z
# Extracting data from post: CoPxYyxJBs4
# Extracted data from post: CoPxYyxJBs4
# Extracting data from post: CoNJ-J5pAJj
# Extracted data from post: CoNJ-J5pAJj
# Extracting data from post: CoKfDDOJey1
# Extracted data from post: CoKfDDOJey1
# Extracting data from post: CoH8vdhpMWd
# Extracted data from post: CoH8vdhpMWd
# Extracting data from post: CoFWW4Fpuy6
# Extracted data from post: CoFWW4Fpuy6
# Extracting data from post: CoCzifrJPPq
# Extracted data from post: CoCzifrJPPq
# Extracting data from post: CoAQ-AFS7ov
# Extracted data from post: CoAQ-AFS7ov
# Extracting data from post: Cn9rRKMS6sL
# Extracted data from post: Cn9rRKMS6sL
# Extracting data from post: Cn7CBavyPfJ
# Extracted data from post: Cn7CBavyPfJ
# Extracting data from post: Cn4mQ50SLA0
# Extracted data from post: Cn4mQ50SLA0
# Extracting data from post: CnzYTO5JA3V
# Extracted data from post: CnzYTO5JA3V
# Extracting data from post: CnuGneCqTYM
# Extracted data from post: CnuGneCqTYM
# Extracting data from post: Cno-hl4qGq-
# Extracted data from post: Cno-hl4qGq-
# Extracting data from post: Cnmd1kppUSa
# Extracted data from post: Cnmd1kppUSa
# Extracting data from post: CnjxMaYKk6O
# Extracted data from post: CnjxMaYKk6O
# Extracting data from post: CnhT-LKJPjT
# Extracted data from post: CnhT-LKJPjT
# Extracting data from post: CneullupvAK
# Extracted data from post: CneullupvAK
# Extracting data from post: CnZl3ncKG5X
# Extracted data from post: CnZl3ncKG5X
# Extracting data from post: CnW77T0qmiQ
# Extracted data from post: CnW77T0qmiQ
# Extracting data from post: CnV2AtSKMBr
# Extracted data from post: CnV2AtSKMBr
# Extracting data from post: CnUdaewKEru
# Extracted data from post: CnUdaewKEru
# Extracting data from post: CnRwJ8nJsrH
# Extracted data from post: CnRwJ8nJsrH
# Extracting data from post: CnPQEIOpILg
# Extracted data from post: CnPQEIOpILg
# Extracting data from post: CnE9GLAKryp
# Extracted data from post: CnE9GLAKryp
# Extracting data from post: CnCMLQzDj5w
# Extracted data from post: CnCMLQzDj5w
# Extracting data from post: Cm_9qxDS-z7
# Extracted data from post: Cm_9qxDS-z7
# Extracting data from post: Cm9I5Qxjju7
# Extracted data from post: Cm9I5Qxjju7
# Extracting data from post: Cm4EdB-DU6p
# Extracted data from post: Cm4EdB-DU6p
# Extracting data from post: Cm3cj5EjLay
# Extracted data from post: Cm3cj5EjLay
# Extracting data from post: Cm0lYmqKZeG
# Extracted data from post: Cm0lYmqKZeG
# Extracting data from post: Cmy8izyqKcF
# Extracted data from post: Cmy8izyqKcF
# Extracting data from post: CmwE4bxKr0x
# Extracted data from post: CmwE4bxKr0x
# Extracting data from post: CmrJ1lwJwKC
# Extracted data from post: CmrJ1lwJwKC
# Extracting data from post: CmonRUcpX99
# Extracted data from post: CmonRUcpX99
# Extracting data from post: CmmA88-Ji9L
# Extracted data from post: CmmA88-Ji9L
# Extracting data from post: CmjXfH5pRIS
# Extracted data from post: CmjXfH5pRIS
# Extracting data from post: Cmis2atKvSe
# Extracted data from post: Cmis2atKvSe
# Extracting data from post: CmguuMFqjrB
# Extracted data from post: CmguuMFqjrB
# Extracting data from post: CmbgLZhpV57
# Extracted data from post: CmbgLZhpV57
# Extracting data from post: CmWQPXYJBx6
# Extracted data from post: CmWQPXYJBx6
# Extracting data from post: CmTEZ1QrzgN
# Extracted data from post: CmTEZ1QrzgN
# Extracting data from post: CmOv_6LJpgY
# Extracted data from post: CmOv_6LJpgY
# Extracting data from post: CmMYFxcp3WY
# Extracted data from post: CmMYFxcp3WY
# Extracting data from post: CmJsYirJ3Q8
# Extracted data from post: CmJsYirJ3Q8
# Extracting data from post: CmEdxHupxOX
# Extracted data from post: CmEdxHupxOX
# Extracting data from post: CmCDDHyJHTH
# Extracted data from post: CmCDDHyJHTH
# Extracting data from post: Cl_U0uvJ4H7
# Extracted data from post: Cl_U0uvJ4H7
# Extracting data from post: Cl8uiY1p6Qe
# Extracted data from post: Cl8uiY1p6Qe
# Extracting data from post: Cl6OfTRp49C
# Extracted data from post: Cl6OfTRp49C
# Extracting data from post: Clv-m1wJIjO
# Extracted data from post: Clv-m1wJIjO
# Extracting data from post: Clq5u1ppAKd
# Extracted data from post: Clq5u1ppAKd
# Extracting data from post: CloIFV7pkFq
# Extracted data from post: CloIFV7pkFq
# Extracting data from post: ClluFMzJ05H
# Extracted data from post: ClluFMzJ05H
# Extracting data from post: Clgekzbp8RP
# Extracted data from post: Clgekzbp8RP
# Extracting data from post: CleBjcSJ1iu
# Extracted data from post: CleBjcSJ1iu
# Extracting data from post: ClZDq3HS537
# Extracted data from post: ClZDq3HS537
# Extracting data from post: ClWQcf7J9ac
# Extracted data from post: ClWQcf7J9ac
# Extracting data from post: ClOecQMJ_1z
# Extracted data from post: ClOecQMJ_1z
# Extracting data from post: ClL9yozSMXc
# Extracted data from post: ClL9yozSMXc
# Extracting data from post: ClIp7ZiDtyd
# Extracted data from post: ClIp7ZiDtyd
# Extracting data from post: ClEPq27SrNQ
# Extracted data from post: ClEPq27SrNQ
# Extracting data from post: Ck_B6wohJL6
# Extracted data from post: Ck_B6wohJL6
# Extracting data from post: Ck7ijnLJ2aO
# Extracted data from post: Ck7ijnLJ2aO
# Extracting data from post: Ck4351AgWL1
# Extracted data from post: Ck4351AgWL1
# Extracting data from post: Ck015q0JiZA
# Extracted data from post: Ck015q0JiZA
# Extracting data from post: CkyHP7ErAyh
# Extracted data from post: CkyHP7ErAyh
# Extracting data from post: CkvfSdUpmrB
# Extracted data from post: CkvfSdUpmrB
# Extracting data from post: CkvA4X7ptWC
# Extracted data from post: CkvA4X7ptWC
# Extracting data from post: Cks40vbpQqT
# Extracted data from post: Cks40vbpQqT
# Extracting data from post: CkqtxpzSwHS
# Extracted data from post: CkqtxpzSwHS
# Extracting data from post: Ckn_jB7J0T-
# Extracted data from post: Ckn_jB7J0T-
# Extracting data from post: Ckk5_apJKiC
# Extracted data from post: Ckk5_apJKiC
# Extracting data from post: CkivS5hg7Cg
# Extracted data from post: CkivS5hg7Cg
# Extracting data from post: CkgEIE-JAsi
# Extracted data from post: CkgEIE-JAsi
# Extracting data from post: CkdZm6TpNK6
# Extracted data from post: CkdZm6TpNK6
# Extracting data from post: CkbJQZgJJyi
# Extracted data from post: CkbJQZgJJyi
# Extracting data from post: CkTOVY6JgI0
# Extracted data from post: CkTOVY6JgI0
# Extracting data from post: CkQm8fgJnQ-
# Extracted data from post: CkQm8fgJnQ-
# Extracting data from post: CkOFHvQJkWz
# Extracted data from post: CkOFHvQJkWz
# Extracting data from post: CkLNmRUJZEH
# Extracted data from post: CkLNmRUJZEH
# Extracting data from post: CkFbmpzJx8N
# Extracted data from post: CkFbmpzJx8N
# Extracting data from post: Cj-vcpHp7-M
# Extracted data from post: Cj-vcpHp7-M
# Extracting data from post: Cj8Xq7BS2Wx
# Extracted data from post: Cj8Xq7BS2Wx
# Extracting data from post: Cj5dmRaJD9m
# Extracted data from post: Cj5dmRaJD9m
# Extracting data from post: Cj23j-hpdmS
# Extracted data from post: Cj23j-hpdmS
# Extracting data from post: CjsoHQepAIq
# Extracted data from post: CjsoHQepAIq
# Extracting data from post: CjqCAOxpduR
# Extracted data from post: CjqCAOxpduR
# Extracting data from post: CjiZeNGpGss
# Extracted data from post: CjiZeNGpGss
# Extracting data from post: CjajnybpV1b
# Extracted data from post: CjajnybpV1b
# Extracting data from post: CjYDfY1pldQ
# Extracted data from post: CjYDfY1pldQ
# Extracting data from post: CjVfbWip-S1
# Extracted data from post: CjVfbWip-S1
# Extracting data from post: CjS4w-Upboy
# Extracted data from post: CjS4w-Upboy
# Extracting data from post: CjQSL88Jkin
# Extracted data from post: CjQSL88Jkin
# Extracting data from post: CjNz16ppJDX
# Extracted data from post: CjNz16ppJDX
# Extracting data from post: CjIeMonJuBw
# Extracted data from post: CjIeMonJuBw
# Extracting data from post: CjGOCv9p5uI
# Extracted data from post: CjGOCv9p5uI
# Extracting data from post: CjAy6RxpE9w
# Extracted data from post: CjAy6RxpE9w
# Extracting data from post: CixXQw8jyk8
# Extracted data from post: CixXQw8jyk8
# Extracting data from post: CiuvvJ8pJxl
# Extracted data from post: CiuvvJ8pJxl
# Extracting data from post: CisEIRVJtgA
# Extracted data from post: CisEIRVJtgA
# Extracting data from post: Cip7ImqpZg4
# Extracted data from post: Cip7ImqpZg4
# Extracting data from post: CikpmagJEqi
# Extracted data from post: CikpmagJEqi
# Extracting data from post: Cih2t-lpqyb
# Extracted data from post: Cih2t-lpqyb
# Extracting data from post: Cifa8TkpuC6
# Extracted data from post: Cifa8TkpuC6
# Extracting data from post: CicCdlspgLm
# Extracted data from post: CicCdlspgLm
# Extracting data from post: CiX66kYpZMM
# Extracted data from post: CiX66kYpZMM
# Extracting data from post: CiU9K8oJnET
# Extracted data from post: CiU9K8oJnET
# Extracting data from post: CiP3Y-FJsFb
# Extracted data from post: CiP3Y-FJsFb
# Extracting data from post: CiNRRBppvgv
# Extracted data from post: CiNRRBppvgv
# Extracting data from post: CiKrlBHpSzz
# Extracted data from post: CiKrlBHpSzz
# Extracting data from post: CiIiUhapn25
# Extracted data from post: CiIiUhapn25
# Extracting data from post: CiHezTvgM2P
# Extracted data from post: CiHezTvgM2P
# Extracting data from post: CiFWJu8JHUQ
# Extracted data from post: CiFWJu8JHUQ
# Extracting data from post: CiC82YVpXm8
# Extracted data from post: CiC82YVpXm8
# Extracting data from post: Ch90f8MJ460
# Extracted data from post: Ch90f8MJ460
# Extracting data from post: Ch7QvEaJS4E
# Extracted data from post: Ch7QvEaJS4E
# Extracting data from post: Ch4vssFpolM
# Extracted data from post: Ch4vssFpolM
# Extracting data from post: Ch2KGRZJJSe
# Extracted data from post: Ch2KGRZJJSe
# Extracting data from post: ChzZWWfDGKY
# Extracted data from post: ChzZWWfDGKY
# Extracting data from post: ChuclK8JhTa
# Extracted data from post: ChuclK8JhTa
# Extracting data from post: ChmoF1HJitJ
# Extracted data from post: ChmoF1HJitJ
# Extracting data from post: ChkMAzXJYk9
# Extracted data from post: ChkMAzXJYk9
# Extracting data from post: ChhhpgwhZbh
# Extracted data from post: ChhhpgwhZbh
# Extracting data from post: ChZzTH2prjA
# Extracted data from post: ChZzTH2prjA
# Extracting data from post: ChXPS_ADT6O
# Extracted data from post: ChXPS_ADT6O
# Extracting data from post: ChUm2GXqOsk
# Extracted data from post: ChUm2GXqOsk
# Extracting data from post: ChQ_vE_jV_E
# Extracted data from post: ChQ_vE_jV_E
# Extracting data from post: ChKVTOHDmAv
# Extracted data from post: ChKVTOHDmAv
# Extracting data from post: ChGyogbpRdg
# Extracted data from post: ChGyogbpRdg
# Extracting data from post: ChFKa0ejerQ
# Extracted data from post: ChFKa0ejerQ
# Extracting data from post: ChCm_xZpqY7
# Extracted data from post: ChCm_xZpqY7
# Extracting data from post: ChAABMJDPa2
# Extracted data from post: ChAABMJDPa2
# Extracting data from post: Cg7BJtTpuQo
# Extracted data from post: Cg7BJtTpuQo
# Extracting data from post: Cg1yj27pGNM
# Extracted data from post: Cg1yj27pGNM
# Extracting data from post: CgzNjw-pKSe
# Extracted data from post: CgzNjw-pKSe
# Extracting data from post: Cgwhi-lDmyM
# Extracted data from post: Cgwhi-lDmyM
# Extracting data from post: CgrYvR5JW5a
# Extracted data from post: CgrYvR5JW5a
# Extracting data from post: CgmRnIXJF7y
# Extracted data from post: CgmRnIXJF7y
# Extracting data from post: Cgj7gSMJvdb
# Extracted data from post: Cgj7gSMJvdb
# Extracting data from post: CghAOyYDS52
# Extracted data from post: CghAOyYDS52
# Extracting data from post: Cgb3S5YjxFB
# Extracted data from post: Cgb3S5YjxFB
# Extracting data from post: CgUZrApDw7n
# Extracted data from post: CgUZrApDw7n
# Extracting data from post: CgRu2VepgYV
# Extracted data from post: CgRu2VepgYV
# Extracting data from post: CgPN7FbJCvi
# Extracted data from post: CgPN7FbJCvi
# Extracting data from post: CgMp1w6pOAZ
# Extracted data from post: CgMp1w6pOAZ
# Extracting data from post: CgCSy47pA-G
# Extracted data from post: CgCSy47pA-G
# Extracting data from post: Cf_ifp-DJyZ
# Extracted data from post: Cf_ifp-DJyZ
# Extracting data from post: Cf4cuGxhiDF
# Extracted data from post: Cf4cuGxhiDF
# Extracting data from post: Cfy2vr8pSx4
# Extracted data from post: Cfy2vr8pSx4
# Extracting data from post: CfwRHvDpH_x
# Extracted data from post: CfwRHvDpH_x
# Extracting data from post: CfrIDJ5D4c2
# Extracted data from post: CfrIDJ5D4c2
# Extracting data from post: Cfirqfqj71T
# Extracted data from post: Cfirqfqj71T
# Extracting data from post: CfeFCYWJieZ
# Extracted data from post: CfeFCYWJieZ
# Extracting data from post: CfbkuFLp2US
# Extracted data from post: CfbkuFLp2US
# Extracting data from post: CfUGIchpgkc
# Extracted data from post: CfUGIchpgkc
# Extracting data from post: CfRQcSFJ-2q
# Extracted data from post: CfRQcSFJ-2q
# Extracting data from post: CfO0bSsJKaQ
# Extracted data from post: CfO0bSsJKaQ
# Extracting data from post: CfMU8tzjaY2
# Extracted data from post: CfMU8tzjaY2
# Extracting data from post: CfHKev5pzWN
# Extracted data from post: CfHKev5pzWN
# Extracting data from post: CfGkA_0psQm
# Extracted data from post: CfGkA_0psQm
# Extracting data from post: Ce-fEm4jbcw
# Extracted data from post: Ce-fEm4jbcw
# Extracting data from post: Ce8UQEIjnUe
# Extracted data from post: Ce8UQEIjnUe
# Extracting data from post: Ce6B_MzJimN
# Extracted data from post: Ce6B_MzJimN
# Extracting data from post: Ce3oYdgDOoa
# Extracted data from post: Ce3oYdgDOoa
# Extracting data from post: Ce0-50JJ3kM
# Extracted data from post: Ce0-50JJ3kM
# Extracting data from post: Ce0uYc5pL-5
# Extracted data from post: Ce0uYc5pL-5
# Extracting data from post: CeyGxmrJykj
# Extracted data from post: CeyGxmrJykj
# Extracting data from post: Cev5lwxpQ1v
# Extracted data from post: Cev5lwxpQ1v
# Extracting data from post: CeoHpYhJ5FO
# Extracted data from post: CeoHpYhJ5FO
# Extracting data from post: Cely6BRjLAZ
# Extracted data from post: Cely6BRjLAZ
# Extracting data from post: CeleOwRDjnf
# Extracted data from post: CeleOwRDjnf
# Extracting data from post: CegWEAFD2w6
# Extracted data from post: CegWEAFD2w6
# Extracting data from post: CeduqGLjfvP
# Extracted data from post: CeduqGLjfvP
# Extracting data from post: CebZqzfpTx2
# Extracted data from post: CebZqzfpTx2
# Extracting data from post: CeWLMEBpy6V
# Extracted data from post: CeWLMEBpy6V
# Extracting data from post: CeTlKzxpnwR
# Extracted data from post: CeTlKzxpnwR
# Extracting data from post: CeOWRXtJRzz
# Extracted data from post: CeOWRXtJRzz
# Extracting data from post: CeLqD7HjIFX
# Extracted data from post: CeLqD7HjIFX
# Extracting data from post: CeGvmYjjMhG
# Extracted data from post: CeGvmYjjMhG
# Extracting data from post: CeEVNaJDlCZ
# Extracted data from post: CeEVNaJDlCZ
# Extracting data from post: CeEEPh1j56B
# Extracted data from post: CeEEPh1j56B
# Extracting data from post: CeBp8Pgj1zY
# Extracted data from post: CeBp8Pgj1zY
# Extracting data from post: CeBcJj-p_G6
# Extracted data from post: CeBcJj-p_G6
# Extracting data from post: Cd-_8DEJXkc
# Extracted data from post: Cd-_8DEJXkc
# Extracting data from post: Cd91SvRjNBk
# Extracted data from post: Cd91SvRjNBk
# Extracting data from post: Cd8bhkGp447
# Extracted data from post: Cd8bhkGp447
# Extracting data from post: Cd57pnCDT36
# Extracted data from post: Cd57pnCDT36
# Extracting data from post: Cd3X8FkJPgX
# Extracted data from post: Cd3X8FkJPgX
# Extracting data from post: Cd3GIl5paaJ
# Extracted data from post: Cd3GIl5paaJ
# Extracting data from post: Cd0pDY3jTVB
# Extracted data from post: Cd0pDY3jTVB
# Extracting data from post: CdyJFCZjHWr
# Extracted data from post: CdyJFCZjHWr
# Extracting data from post: Cdvm0cBpBTt
# Extracted data from post: Cdvm0cBpBTt
# Extracting data from post: Cds7F_GJmWK
# Extracted data from post: Cds7F_GJmWK
# Extracting data from post: CdqduympOor
# Extracted data from post: CdqduympOor
# Extracting data from post: CdpsdKcD1hh
# Extracted data from post: CdpsdKcD1hh
# Extracting data from post: CdnqzcyJVh7
# Extracted data from post: CdnqzcyJVh7
# Extracting data from post: CdgGuTvpmMz
# Extracted data from post: CdgGuTvpmMz
# Extracting data from post: Cda8V_cpCPT
# Extracted data from post: Cda8V_cpCPT
# Extracting data from post: CdYh0BqDr6M
# Extracted data from post: CdYh0BqDr6M
# Extracting data from post: CdVsitbJ6P5
# Extracted data from post: CdVsitbJ6P5
# Extracting data from post: CdSZjcWDnpC
# Extracted data from post: CdSZjcWDnpC
# Extracting data from post: CdODBQejRey
# Extracted data from post: CdODBQejRey
# Extracting data from post: CdLoJdcJUef
# Extracted data from post: CdLoJdcJUef
# Extracting data from post: CdI5E6SJziq
# Extracted data from post: CdI5E6SJziq
# Extracting data from post: CdIncyaJ2QD
# Extracted data from post: CdIncyaJ2QD
# Extracting data from post: CdDv_qiJqR5
# Extracted data from post: CdDv_qiJqR5
# Extracting data from post: CdBLXuJpa8K
# Extracted data from post: CdBLXuJpa8K
# Extracting data from post: Cc-u9Xhp5sz
# Extracted data from post: Cc-u9Xhp5sz
# Extracting data from post: Cc-cJxIJvwI
# Extracted data from post: Cc-cJxIJvwI
# Extracting data from post: Cc7-EpJJINx
# Extracted data from post: Cc7-EpJJINx
# Extracting data from post: Cc7g30SJ_yt
# Extracted data from post: Cc7g30SJ_yt
# Extracting data from post: Cc7EKitJMZ3
# Extracted data from post: Cc7EKitJMZ3
# Extracting data from post: Cc5YHysD0WH
# Extracted data from post: Cc5YHysD0WH
# Extracting data from post: Cc2tIBZpJRZ
# Extracted data from post: Cc2tIBZpJRZ
# Extracting data from post: Cc0IKrPD2VN
# Extracted data from post: Cc0IKrPD2VN
# Extracting data from post: CcxTTxrDxn0
# Extracted data from post: CcxTTxrDxn0
# Extracting data from post: CcqABsqJ15A
# Extracted data from post: CcqABsqJ15A
# Extracting data from post: CcpkBcypACH
# Extracted data from post: CcpkBcypACH
# Extracting data from post: CckgE2EDWOT
# Extracted data from post: CckgE2EDWOT
# Extracting data from post: CciRe4ED_3B
# Extracted data from post: CciRe4ED_3B
# Extracting data from post: Ccf0_T9DMAY
# Extracted data from post: Ccf0_T9DMAY
# Extracting data from post: CcfliFJjcBL
# Extracted data from post: CcfliFJjcBL
# Extracting data from post: CcdCZzupgjg
# Extracted data from post: CcdCZzupgjg
# Extracting data from post: CcX3qxOpBUs
# Extracted data from post: CcX3qxOpBUs
# Extracting data from post: CcVPno8pWnt
# Extracted data from post: CcVPno8pWnt
# Extracting data from post: CcS6rq3KhtD
# Extracted data from post: CcS6rq3KhtD
# Extracting data from post: CcSePqRhkS0
# Extracted data from post: CcSePqRhkS0
# Extracting data from post: CcP4yADj9sa
# Extracted data from post: CcP4yADj9sa
# Extracting data from post: CcMud63j4DO
# Extracted data from post: CcMud63j4DO
# Extracting data from post: CcH0GUpDL1x
# Extracted data from post: CcH0GUpDL1x
# Extracting data from post: CcFxhRHjvQC
# Extracted data from post: CcFxhRHjvQC
# Extracting data from post: CcDGfDoJqAF
# Extracted data from post: CcDGfDoJqAF
# Extracting data from post: CcAgzv_pjQN
# Extracted data from post: CcAgzv_pjQN
# Extracting data from post: Cb955jAJbnL
# Extracted data from post: Cb955jAJbnL
# Extracting data from post: Cb7RyTEpXDA
# Extracted data from post: Cb7RyTEpXDA
# Extracting data from post: Cb2hTarjOOT
# Extracted data from post: Cb2hTarjOOT
# Extracting data from post: Cbujfi8Dcy1
# Extracted data from post: Cbujfi8Dcy1
# Extracting data from post: CbrwRO5DL_v
# Extracted data from post: CbrwRO5DL_v
# Extracting data from post: CbpHnfEpIBT
# Extracted data from post: CbpHnfEpIBT
# Extracting data from post: CbkVhEkJ0dZ
# Extracted data from post: CbkVhEkJ0dZ
# Extracting data from post: CbhqsX6DvRD
# Extracted data from post: CbhqsX6DvRD
# Extracting data from post: CbfE5BeJ6HH
# Extracted data from post: CbfE5BeJ6HH
# Extracting data from post: CbcfzcoDhjt
# Extracted data from post: CbcfzcoDhjt
# Extracting data from post: CbZ3c2yjwV_
# Extracted data from post: CbZ3c2yjwV_
# Extracting data from post: CbXfv6tpM2V
# Extracted data from post: CbXfv6tpM2V
# Extracting data from post: CbU4Wg1jv4X
# Extracted data from post: CbU4Wg1jv4X
# Extracting data from post: CbSUqeoDjTt
# Extracted data from post: CbSUqeoDjTt
# Extracting data from post: CbP0W30D4DO
# Extracted data from post: CbP0W30D4DO
# Extracting data from post: CbNXLm9pzt_
# Extracted data from post: CbNXLm9pzt_
# Extracting data from post: CbKWxP5paKL
# Extracted data from post: CbKWxP5paKL
# Extracting data from post: CbH_qhRjFU1
# Extracted data from post: CbH_qhRjFU1
# Extracting data from post: CbFU90SJx5L
# Extracted data from post: CbFU90SJx5L
# Extracting data from post: CbDBGQOpBOu
# Extracted data from post: CbDBGQOpBOu
# Extracting data from post: Ca9oBi3DcEY
# Extracted data from post: Ca9oBi3DcEY
# Extracting data from post: Ca6xWxvj9xg
# Extracted data from post: Ca6xWxvj9xg
# Extracting data from post: Ca4_I5tDa8z
# Extracted data from post: Ca4_I5tDa8z
# Extracting data from post: Ca2BgOFuzDQ
# Extracted data from post: Ca2BgOFuzDQ
# Extracting data from post: Ca1tWVkjv-8
# Extracted data from post: Ca1tWVkjv-8
# Extracting data from post: Caz34lEBo5J
# Extracted data from post: Caz34lEBo5J
# Extracting data from post: CazIj84unk2
# Extracted data from post: CazIj84unk2
# Extracting data from post: Carm6Qep9Kp
# Extracted data from post: Carm6Qep9Kp
# Extracting data from post: CapPg-JDW72
# Extracted data from post: CapPg-JDW72
# Extracting data from post: Cam0OwgpLKm
# Extracted data from post: Cam0OwgpLKm
# Extracting data from post: Caj_XqKDX5Y
# Extracted data from post: Caj_XqKDX5Y
# Extracting data from post: CahYnTXDv6D
# Extracted data from post: CahYnTXDv6D
# Extracting data from post: Cae7oOjDaPm
# Extracted data from post: Cae7oOjDaPm
# Extracting data from post: CacCUOMpAZr
# Extracted data from post: CacCUOMpAZr
# Extracting data from post: CaZpP-_DJi3
# Extracted data from post: CaZpP-_DJi3
# Extracting data from post: CaW_Hl_ONaB
# Extracted data from post: CaW_Hl_ONaB
# Extracting data from post: CaUO6w5jrT6
# Extracted data from post: CaUO6w5jrT6
# Extracting data from post: CaRgXEcDCVb
# Extracted data from post: CaRgXEcDCVb
# Extracting data from post: CaPTzHyjqKV
# Extracted data from post: CaPTzHyjqKV
# Extracting data from post: CaMzdimpMfu
# Extracted data from post: CaMzdimpMfu
# Extracting data from post: CaMIV6PjEDl
# Extracted data from post: CaMIV6PjEDl
# Extracting data from post: CaKNDi7jset
# Extracted data from post: CaKNDi7jset
# Extracting data from post: CaHxwVNpart
# Extracted data from post: CaHxwVNpart
# Extracting data from post: CaFKWUVjL_u
# Extracted data from post: CaFKWUVjL_u
# Extracting data from post: CaCm72KJjze
# Extracted data from post: CaCm72KJjze
# Extracting data from post: CZ_-CKpDCSl
# Extracted data from post: CZ_-CKpDCSl
# Extracting data from post: CZ9Yc-KJ9sN
# Extracted data from post: CZ9Yc-KJ9sN
# Extracting data from post: CZ9C523pmAe
# Extracted data from post: CZ9C523pmAe
# Extracting data from post: CZ8l2N2KF7c
# Extracted data from post: CZ8l2N2KF7c
# Extracting data from post: CZ6sFfLBPI0
# Extracted data from post: CZ6sFfLBPI0
# Extracting data from post: CZ1wNmEpA7c
# Extracted data from post: CZ1wNmEpA7c
# Extracting data from post: CZwhThYDG_4
# Extracted data from post: CZwhThYDG_4
# Extracting data from post: CZt80-1pPHD
# Extracted data from post: CZt80-1pPHD
# Extracting data from post: CZrkx9TpI8y
# Extracted data from post: CZrkx9TpI8y
# Extracting data from post: CZot-_mj7ug
# Extracted data from post: CZot-_mj7ug
# Extracting data from post: CZjw3A-Jk-I
# Extracted data from post: CZjw3A-Jk-I
# Extracting data from post: CZhKJ-Fpm4G
# Extracted data from post: CZhKJ-Fpm4G
# Extracting data from post: CZcGifKpipF
# Extracted data from post: CZcGifKpipF
# Extracting data from post: CZZgMZAq1I_
# Extracted data from post: CZZgMZAq1I_
# Extracting data from post: CZWv9zbJGKl
# Extracted data from post: CZWv9zbJGKl
# Extracting data from post: CZRpjMDJ5k3
# Extracted data from post: CZRpjMDJ5k3
# Extracting data from post: CZPHCmlDw1d
# Extracted data from post: CZPHCmlDw1d
# Extracting data from post: CZLzdbeqc-a
# Extracted data from post: CZLzdbeqc-a
# Extracting data from post: CZKGWI4qEz7
# Extracted data from post: CZKGWI4qEz7
# Extracting data from post: CZHcs29qZ2r
# Extracted data from post: CZHcs29qZ2r
# Extracting data from post: CY_sfuiqY6W
# Extracted data from post: CY_sfuiqY6W
# Extracting data from post: CY_d-pAqTvD
# Extracted data from post: CY_d-pAqTvD
# Extracting data from post: CY342FepaXh
# Extracted data from post: CY342FepaXh
# Extracting data from post: CYywBf-p304
# Extracted data from post: CYywBf-p304
# Extracting data from post: CYtqAkxJNV_
# Extracted data from post: CYtqAkxJNV_
# Extracting data from post: CYsuD9MK57l
# Extracted data from post: CYsuD9MK57l
# Extracting data from post: CYrQDVjpvYI
# Extracted data from post: CYrQDVjpvYI
# Extracting data from post: CYogJ3uq4v1
# Extracted data from post: CYogJ3uq4v1
# Extracting data from post: CYmGQgQJ0lv
# Extracted data from post: CYmGQgQJ0lv
# Extracting data from post: CYjRKlapRo4
# Extracted data from post: CYjRKlapRo4
# Extracting data from post: CYgqGDrKgym
# Extracted data from post: CYgqGDrKgym
# Extracting data from post: CYbrhEIpWCk
# Extracted data from post: CYbrhEIpWCk
# Extracting data from post: CYY_mHmqNyw
# Extracted data from post: CYY_mHmqNyw
# Extracting data from post: CYWdxYbJspa
# Extracted data from post: CYWdxYbJspa
# Extracting data from post: CYRUWnRpanK
# Extracted data from post: CYRUWnRpanK
# Extracting data from post: CYJi3zfpOmM
# Extracted data from post: CYJi3zfpOmM
# Extracting data from post: CYI03cjpOZO
# Extracted data from post: CYI03cjpOZO
# Extracting data from post: CYEc3HxpSBy
# Extracted data from post: CYEc3HxpSBy
# Extracting data from post: CYBzk7wqdFX
# Extracted data from post: CYBzk7wqdFX
# Extracting data from post: CX3uq9Dqgdz
# Extracted data from post: CX3uq9Dqgdz
# Extracting data from post: CX0_qESKm7b
# Extracted data from post: CX0_qESKm7b
# Extracting data from post: CXygBTUJ5yy
# Extracted data from post: CXygBTUJ5yy
# Extracting data from post: CXv4UiLpVAy
# Extracted data from post: CXv4UiLpVAy
# Extracting data from post: CXqePOvJKR9
# Extracted data from post: CXqePOvJKR9
# Extracting data from post: CXlu2cfpMtf
# Extracted data from post: CXlu2cfpMtf
# Extracting data from post: CXYylEgpPXN
# Extracted data from post: CXYylEgpPXN
# Extracting data from post: CXTWyKsprfS
# Extracted data from post: CXTWyKsprfS
# Extracting data from post: CXRHtt2pxWI
# Extracted data from post: CXRHtt2pxWI
# Extracting data from post: CXLz00AJZ9d
# Extracted data from post: CXLz00AJZ9d
# Extracting data from post: CXJLDh0pVOF
# Extracted data from post: CXJLDh0pVOF
# Extracting data from post: CXBX64mJ0It
# Extracted data from post: CXBX64mJ0It
# Extracting data from post: CW-8tmpB24Y
# Extracted data from post: CW-8tmpB24Y
# Extracting data from post: CW8Tr_yBHBg
# Extracted data from post: CW8Tr_yBHBg
# Extracting data from post: CW3YDdhh-cw
# Extracted data from post: CW3YDdhh-cw
# Extracting data from post: CW0iNE_JSj5
# Extracted data from post: CW0iNE_JSj5
# Extracting data from post: CWvYRq4pv5i
# Extracted data from post: CWvYRq4pv5i
# Extracting data from post: CWtAKLzh4Bl
# Extracted data from post: CWtAKLzh4Bl
# Extracting data from post: CWqfpA1h_v_
# Extracted data from post: CWqfpA1h_v_
# Extracting data from post: CWlPBkFvdfN
# Extracted data from post: CWlPBkFvdfN
# Extracting data from post: CWgCGzLBp0h
# Extracted data from post: CWgCGzLBp0h
# Extracting data from post: CWa9YeJjIS-
# Extracted data from post: CWa9YeJjIS-
# Extracting data from post: CWVtNt5gAKz
# Extracted data from post: CWVtNt5gAKz
# Extracting data from post: CWPkEnyJ2Eq
# Extracted data from post: CWPkEnyJ2Eq
# Extracting data from post: CWLURAVD3PM
# Extracted data from post: CWLURAVD3PM
# Extracting data from post: CWI0gu1DtjX
# Extracted data from post: CWI0gu1DtjX
# Extracting data from post: CWDx_FAjFXZ
# Extracted data from post: CWDx_FAjFXZ
# Extracting data from post: CWBL5o5Dehd
# Extracted data from post: CWBL5o5Dehd
# Extracting data from post: CV732RcBJeJ
# Extracted data from post: CV732RcBJeJ
# Extracting data from post: CV109phpMpr
# Extracted data from post: CV109phpMpr
# Extracting data from post: CVxkxg3B7LW
# Extracted data from post: CVxkxg3B7LW
# Extracting data from post: CVu9BHsh1jS
# Extracted data from post: CVu9BHsh1jS
# Extracting data from post: CVrjymcp46Z
# Extracted data from post: CVrjymcp46Z
# Extracting data from post: CVndScvDibe
# Extracted data from post: CVndScvDibe
# Extracting data from post: CVk4Ds4D6ev
# Extracted data from post: CVk4Ds4D6ev
# Extracting data from post: CVihGkajE6T
# Extracted data from post: CVihGkajE6T
# Extracting data from post: CVfoZ-3hkSZ
# Extracted data from post: CVfoZ-3hkSZ
# Extracting data from post: CVdGCC6MIjz
# Extracted data from post: CVdGCC6MIjz
# Extracting data from post: CVVfAqbjAoy
# Extracted data from post: CVVfAqbjAoy
# Extracting data from post: CVQPadSp_eu
# Extracted data from post: CVQPadSp_eu
# Extracting data from post: CVNpna4jDds
# Extracted data from post: CVNpna4jDds
# Extracting data from post: CVLO-nUj1nt
# Extracted data from post: CVLO-nUj1nt
# Extracting data from post: CVF8XfaDn3D
# Extracted data from post: CVF8XfaDn3D
# Extracting data from post: CVAvQmaDOLQ
# Extracted data from post: CVAvQmaDOLQ
# Extracting data from post: CUw7YX6heM3
# Extracted data from post: CUw7YX6heM3
# Extracting data from post: CUsJEdHJzN6
# Extracted data from post: CUsJEdHJzN6
# Extracting data from post: CUfboXABOln
# Extracted data from post: CUfboXABOln
# Extracting data from post: CUe8uA3j3NK
# Extracted data from post: CUe8uA3j3NK
# Extracting data from post: CUaPPfTjaJ0
# Extracted data from post: CUaPPfTjaJ0
# Extracting data from post: CUVFaawDBEc
# Extracted data from post: CUVFaawDBEc
# Extracting data from post: CUNNzpgJ08V
# Extracted data from post: CUNNzpgJ08V
# Extracting data from post: CUIIMwGJpCS
# Extracted data from post: CUIIMwGJpCS
# Extracting data from post: CUC3gR5p5rF
# Extracted data from post: CUC3gR5p5rF
# Extracting data from post: CUAZm-spiLi
# Extracted data from post: CUAZm-spiLi
# Extracting data from post: CTuQYUBJqIL
# Extracted data from post: CTuQYUBJqIL
# Extracting data from post: CTr6PlCJO6P
# Extracted data from post: CTr6PlCJO6P
# Extracting data from post: CTmi1RdDHMk
# Extracted data from post: CTmi1RdDHMk
# Extracting data from post: CThcMt7J4F9
# Extracted data from post: CThcMt7J4F9
# Extracting data from post: CTbUF3gpWY1
# Extracted data from post: CTbUF3gpWY1
# Extracting data from post: CTFGXI2jBf9
# Extracted data from post: CTFGXI2jBf9
# Extracting data from post: CTCVpVzJs1a
# Extracted data from post: CTCVpVzJs1a
# Extracting data from post: CS9nlmFjLKh
# Extracted data from post: CS9nlmFjLKh
# Extracting data from post: CS3U1f1Jz6C
# Extracted data from post: CS3U1f1Jz6C
# Extracting data from post: CSy-vdSjwmk
# Extracted data from post: CSy-vdSjwmk
# Extracting data from post: CSwO0XMjhM8
# Extracted data from post: CSwO0XMjhM8
# Extracting data from post: CSo8pnVph2I
# Extracted data from post: CSo8pnVph2I
# Extracting data from post: CSlOjZbpqXM
# Extracted data from post: CSlOjZbpqXM
# Extracting data from post: CSjeiIUJZO0
# Extracted data from post: CSjeiIUJZO0
# Extracting data from post: CSb7OLTJRSY
# Extracted data from post: CSb7OLTJRSY
# Extracting data from post: CSZUbV-DyZr
# Extracted data from post: CSZUbV-DyZr
# Extracting data from post: CSBZVy6Jp7e
# Extracted data from post: CSBZVy6Jp7e
# Extracting data from post: CR1OxBXjrzy
# Extracted data from post: CR1OxBXjrzy
# Extracting data from post: CRyvAHCjnR-
# Extracted data from post: CRyvAHCjnR-
# Extracting data from post: CRoR7u4jUqP
# Extracted data from post: CRoR7u4jUqP
# Extracting data from post: CRjP4FyDy3J
# Extracted data from post: CRjP4FyDy3J
# Extracting data from post: CRapRdNjAEV
# Extracted data from post: CRapRdNjAEV
# Extracting data from post: CRWmK50Dr4x
# Extracted data from post: CRWmK50Dr4x
# Extracting data from post: CRIqegbDIBI
# Extracted data from post: CRIqegbDIBI
# Extracting data from post: CQyc6x3DgjL
# Extracted data from post: CQyc6x3DgjL
# Extracting data from post: CQbfRgWDv_y
# Extracted data from post: CQbfRgWDv_y
# Extracting data from post: CQVDqPRDgqP
# Extracted data from post: CQVDqPRDgqP
# Extracting data from post: CQOgW6Xjn_4
# Extracted data from post: CQOgW6Xjn_4
# Extracting data from post: CQJL1yvjV30
# Extracted data from post: CQJL1yvjV30
# Extracting data from post: CP_GTDODkqm
# Extracted data from post: CP_GTDODkqm
# Extracting data from post: CP5_-GWqhYd
# Extracted data from post: CP5_-GWqhYd
# Extracting data from post: CPqfJ22DmWA
# Extracted data from post: CPqfJ22DmWA
# Extracting data from post: CPlOxoADMPQ
# Extracted data from post: CPlOxoADMPQ
# Extracting data from post: CPYPUbRDIWc
# Extracted data from post: CPYPUbRDIWc
# Extracting data from post: CPP55fFjD1H
# Extracted data from post: CPP55fFjD1H
# Extracting data from post: CPI_OCCDVhe
# Extracted data from post: CPI_OCCDVhe
# Extracting data from post: CPD3eObD6dP
# Extracted data from post: CPD3eObD6dP
# Extracting data from post: CO-35dODv0u
# Extracted data from post: CO-35dODv0u
# Extracting data from post: CO11KUAjHg-
# Extracted data from post: CO11KUAjHg-
# Extracting data from post: COvVfzXjSpX
# Extracted data from post: COvVfzXjSpX
# Extracting data from post: COpn0csDyz7
# Extracted data from post: COpn0csDyz7
# Extracting data from post: COmx6iTDQjN
# Extracted data from post: COmx6iTDQjN
# Extracting data from post: COidZSDDyfo
# Extracted data from post: COidZSDDyfo
# Extracting data from post: COdORycjGj0
# Extracted data from post: COdORycjGj0
# Extracting data from post: CONsFwFjVjI
# Extracted data from post: CONsFwFjVjI
# Extracting data from post: COLJgrjjaWQ
# Extracted data from post: COLJgrjjaWQ
# Extracting data from post: COIQ3HEjIGA
# Extracted data from post: COIQ3HEjIGA
# Extracting data from post: CODHTj7D1yu
# Extracted data from post: CODHTj7D1yu
# Extracting data from post: COAdigzDmzO
# Extracted data from post: COAdigzDmzO
# Extracting data from post: CN-d8QyjqBW
# Extracted data from post: CN-d8QyjqBW
# Extracting data from post: CN7l-ATDfA6
# Extracted data from post: CN7l-ATDfA6
# Extracting data from post: CNxQpBUjVCw
# Extracted data from post: CNxQpBUjVCw
# Extracting data from post: CNkhTL8jrbK
# Extracted data from post: CNkhTL8jrbK
# Extracting data from post: CNcl8C7jGDO
# Extracted data from post: CNcl8C7jGDO
# Extracting data from post: CNZ832vDiuO
# Extracted data from post: CNZ832vDiuO
# Extracting data from post: CNG_7zcDuxN
# Extracted data from post: CNG_7zcDuxN
# Extracting data from post: CNC7Yt2jeOt
# Extracted data from post: CNC7Yt2jeOt
# Extracting data from post: CM2VATID_2d
# Extracted data from post: CM2VATID_2d
# Extracting data from post: CMw8OQ7jOLN
# Extracted data from post: CMw8OQ7jOLN
# Extracting data from post: CMpHNVoDVHd
# Extracted data from post: CMpHNVoDVHd
# Extracting data from post: CMm62xBjQ11
# Extracted data from post: CMm62xBjQ11
# Extracting data from post: CMcMtmcjohS
# Extracted data from post: CMcMtmcjohS
# Extracting data from post: CMWQXYtjEK0
# Extracted data from post: CMWQXYtjEK0
# Extracting data from post: CMKp89Cj81A
# Extracted data from post: CMKp89Cj81A
# Extracting data from post: CMFRSA3jOl4
# Extracted data from post: CMFRSA3jOl4
# Extracting data from post: CL4Qx3gje8q
# Extracted data from post: CL4Qx3gje8q
# Extracting data from post: CL1sqN-Dmsb
# Extracted data from post: CL1sqN-Dmsb
# Extracting data from post: CLrTmAjjaG0
# Extracted data from post: CLrTmAjjaG0
# Extracting data from post: CLmhPGjjfBN
# Extracted data from post: CLmhPGjjfBN
# Extracting data from post: CLehIQiDxJk
# Extracted data from post: CLehIQiDxJk
# Extracting data from post: CLbw6AKjVwi
# Extracted data from post: CLbw6AKjVwi
# Extracting data from post: CLWqwHdDKT-
# Extracted data from post: CLWqwHdDKT-
# Extracting data from post: CLQncI5j2TM
# Extracted data from post: CLQncI5j2TM
# Extracting data from post: CLJwZkHjfZh
# Extracted data from post: CLJwZkHjfZh
# Extracting data from post: CLEmCJvjCd-
# Extracted data from post: CLEmCJvjCd-
# Extracting data from post: CK3unTFjOTA
# Extracted data from post: CK3unTFjOTA
# Extracting data from post: CK1KdV-DK2T
# Extracted data from post: CK1KdV-DK2T
# Extracting data from post: CKwcqyyD15k
# Extracted data from post: CKwcqyyD15k
# Extracting data from post: CKob1PujjcL
# Extracted data from post: CKob1PujjcL
# Extracting data from post: CKWngT9DyWi
# Extracted data from post: CKWngT9DyWi
# Extracting data from post: CKRNWucDlpc
# Extracted data from post: CKRNWucDlpc
# Extracting data from post: CJ_W6yVj2vL
# Extracted data from post: CJ_W6yVj2vL
# Extracting data from post: CJ6PlrljJ6i
# Extracted data from post: CJ6PlrljJ6i
# Extracting data from post: CJyPaw4j43E
# Extracted data from post: CJyPaw4j43E
# Extracting data from post: CJi0y9jjGaY
# Extracted data from post: CJi0y9jjGaY
# Extracting data from post: CJY_PZvjh2r
# Extracted data from post: CJY_PZvjh2r
# Extracting data from post: CJNRz69jlo9
# Extracted data from post: CJNRz69jlo9
# Extracting data from post: CJFqrWqjXJb
# Extracted data from post: CJFqrWqjXJb
# Extracting data from post: CI3BD17DIzd
# Extracted data from post: CI3BD17DIzd
# Extracting data from post: CIxAovmjF1o
# Extracted data from post: CIxAovmjF1o
# Extracting data from post: CIVjNwfjrnH
# Extracted data from post: CIVjNwfjrnH
# Extracting data from post: CIN1Xeejh11
# Extracted data from post: CIN1Xeejh11
# Extracting data from post: CHj9Hfzjb40
# Extracted data from post: CHj9Hfzjb40
# Extracting data from post: CHQGAsSDGg4
# Extracted data from post: CHQGAsSDGg4
# Extracting data from post: CHI4Ttkjt50
# Extracted data from post: CHI4Ttkjt50
# Extracting data from post: CHFt7mdjDDa
# Extracted data from post: CHFt7mdjDDa
# Extracting data from post: CGy4LyKjkIM
# Extracted data from post: CGy4LyKjkIM
# Extracting data from post: CGwURuRj7UC
# Extracted data from post: CGwURuRj7UC
# Extracting data from post: CGZZR5wDeMX
# Extracted data from post: CGZZR5wDeMX
# Extracting data from post: CGYAo6DjPD2
# Extracted data from post: CGYAo6DjPD2
# Extracting data from post: CGWuXnojm9g
# Extracted data from post: CGWuXnojm9g
# Extracting data from post: CFH1YmmhXkF
# Extracted data from post: CFH1YmmhXkF
# Extracting data from post: CE6u4CzhsCP
# Extracted data from post: CE6u4CzhsCP
# Extracting data from post: CEv0XCRBiH_
# Extracted data from post: CEv0XCRBiH_
# Extracting data from post: CELoEISBwre
# Extracted data from post: CELoEISBwre
# Extracting data from post: CDwByZthkHQ
# Extracted data from post: CDwByZthkHQ
# Extracting data from post: CDg1z5kh6_H
# Extracted data from post: CDg1z5kh6_H
# Extracting data from post: CDavQwxBvQK
# Extracted data from post: CDavQwxBvQK
# Extracting data from post: CDL-e-rhfgu
# Extracted data from post: CDL-e-rhfgu
# Extracting data from post: CC8jMHEFF2w
# Extracted data from post: CC8jMHEFF2w
# Extracting data from post: CC0zPQihcDF
# Extracted data from post: CC0zPQihcDF
# Extracting data from post: CCtiNKvBkDX
# Extracted data from post: CCtiNKvBkDX
# Extracting data from post: CClw6Xeh-Wh
# Extracted data from post: CClw6Xeh-Wh
# Extracting data from post: CCaYGFchBug
# Extracted data from post: CCaYGFchBug
# Extracting data from post: CCJCPGGh3yc
# Extracted data from post: CCJCPGGh3yc
# Extracting data from post: CB5mcUoBMay
# Extracted data from post: CB5mcUoBMay
# Extracting data from post: CBsO6hTh3Ve
# Extracted data from post: CBsO6hTh3Ve
# Extracting data from post: CBqY77tB7ql
# Extracted data from post: CBqY77tB7ql
# Extracting data from post: CBgIqPSB5PT
# Extracted data from post: CBgIqPSB5PT
# Extracting data from post: CBCk0rOhHeH
# Extracted data from post: CBCk0rOhHeH
# Extracting data from post: CA7smV4AAhp
# Extracted data from post: CA7smV4AAhp
# Extracting data from post: CAxulNtBzv1
# Extracted data from post: CAxulNtBzv1
# Extracting data from post: CApo3Ngg8Vd
# Extracted data from post: CApo3Ngg8Vd
# Extracting data from post: CApoCFGA3qR
# Extracted data from post: CApoCFGA3qR
# Extracting data from post: CApoAkrAcYp
# Extracted data from post: CApoAkrAcYp
# Extracting data from post: CApeQjYArc4
# Extracted data from post: CApeQjYArc4
# Extracting data from post: CApeGk-Ahf1
# Extracted data from post: CApeGk-Ahf1
# Extracting data from post: CApd5SXgxP_
# Extracted data from post: CApd5SXgxP_
# Extracting data from post: CAk5lWQhSzN
# Extracted data from post: CAk5lWQhSzN
# Extracting data from post: CAk5YvGB_-s
# Extracted data from post: CAk5YvGB_-s
# Extracting data from post: CAkz1qIB7hI
# Extracted data from post: CAkz1qIB7hI
# Extracting data from post: CAkzyiQh_1d
# Extracted data from post: CAkzyiQh_1d
# Extracting data from post: CAfxa8ZhQ9E
# Extracted data from post: CAfxa8ZhQ9E
# Extracting data from post: CAN4ff8BQCr
# Extracted data from post: CAN4ff8BQCr
# Extracting data from post: CAN3eZYB-wv
# Extracted data from post: CAN3eZYB-wv
# Extracting data from post: CAN3VeshYvJ
# Extracted data from post: CAN3VeshYvJ
# Extracting data from post: CABDR0ZhcdK
# Extracted data from post: CABDR0ZhcdK
# Extracting data from post: CAAu5RngLN4
# Extracted data from post: CAAu5RngLN4
# Extracting data from post: CAAaaiDg_yw
# Extracted data from post: CAAaaiDg_yw
# Extracting data from post: B_uyer_B5m6
# Extracted data from post: B_uyer_B5m6
# Extracting data from post: B_upkQZh07K
# Extracted data from post: B_upkQZh07K
# Extracting data from post: B_r4J68BmIM
#
# Too many queries in the last time. Need to wait 22 minutes, until 14:15.
# Extracted data from post: B_r4J68BmIM
# Extracting data from post: B-10TO1BOZJ
# Extracted data from post: B-10TO1BOZJ
# Extracting data from post: B-rwmzJhP5z
# Extracted data from post: B-rwmzJhP5z
# Extracting data from post: B-ro1_TBK2m
# Extracted data from post: B-ro1_TBK2m
# Extracting data from post: B-rjDOfB0nl
# Extracted data from post: B-rjDOfB0nl
# Extracting data from post: B-M8KY2hgQ2
# Extracted data from post: B-M8KY2hgQ2
# Extracting data from post: B-MfKHuhfpU
# Extracted data from post: B-MfKHuhfpU
# Extracting data from post: B914vsTHj_S
# Extracted data from post: B914vsTHj_S
# Extracting data from post: B9bZX59hqzt
# Extracted data from post: B9bZX59hqzt
# Extracting data from post: B8vy5C7hxLF
# Extracted data from post: B8vy5C7hxLF
# Extracting data from post: B8vytn8hwM-
# Extracted data from post: B8vytn8hwM-
# Extracting data from post: B8vwSUEBwvI
# Extracted data from post: B8vwSUEBwvI
# Extracting data from post: B8k5zyFhHpI
# Extracted data from post: B8k5zyFhHpI
# Extracting data from post: B8k5ZdfhYNf
# Extracted data from post: B8k5ZdfhYNf
# Extracting data from post: B8k5B5uBGPJ
# Extracted data from post: B8k5B5uBGPJ
# Extracting data from post: B8YGTBrhzv2
# Extracted data from post: B8YGTBrhzv2
# Extracting data from post: B8YGJz_B7UC
# Extracted data from post: B8YGJz_B7UC
# Extracting data from post: B8YGCh-h3ky
# Extracted data from post: B8YGCh-h3ky
# Extracting data from post: B8LriuZhJaR
# Extracted data from post: B8LriuZhJaR
# Extracting data from post: B8Lrb59BDV7
# Extracted data from post: B8Lrb59BDV7
# Extracting data from post: B8LrPeMByHs
# Extracted data from post: B8LrPeMByHs
# Extracting data from post: B7x_WtTBJ6w
# Extracted data from post: B7x_WtTBJ6w
# Extracting data from post: B7x_Rc7BhS9
# Extracted data from post: B7x_Rc7BhS9
# Extracting data from post: B7x_G2Nh-LA
# Extracted data from post: B7x_G2Nh-LA
# Extracting data from post: B7i5Ktlh7EQ
# Extracted data from post: B7i5Ktlh7EQ
# Extracting data from post: B7bHsa6B_YG
# Extracted data from post: B7bHsa6B_YG
# Extracting data from post: B7VTXFhB5kO
# Extracted data from post: B7VTXFhB5kO
# Extracting data from post: B7VTGnyh0X3
# Extracted data from post: B7VTGnyh0X3
# Extracting data from post: B62efgdBJW1
# Extracted data from post: B62efgdBJW1
# Extracting data from post: B62eXOrhtq9
# Extracted data from post: B62eXOrhtq9
# Extracting data from post: B6flvethJCV
# Extracted data from post: B6flvethJCV
# Extracting data from post: B6fllz4BKU3
# Extracted data from post: B6fllz4BKU3
# Extracting data from post: B6fleYIhW4q
# Extracted data from post: B6fleYIhW4q
# Extracting data from post: B6Vq6G2BYDC
# Extracted data from post: B6Vq6G2BYDC
# Extracting data from post: B6VqnMvh1Oc
# Extracted data from post: B6VqnMvh1Oc
# Extracting data from post: B5-t5qaBozd
# Extracted data from post: B5-t5qaBozd
# Extracting data from post: B5-t297BfOd
# Extracted data from post: B5-t297BfOd
# Extracting data from post: B5-tunIB5V3
# Extracted data from post: B5-tunIB5V3
# Extracting data from post: B5AfO1OBn6b
# Extracted data from post: B5AfO1OBn6b
# Extracting data from post: B5Ae-LqhPXm
# Extracted data from post: B5Ae-LqhPXm
# Extracting data from post: B5Aeqtkh7_B
# Extracted data from post: B5Aeqtkh7_B
# Extracting data from post: B4wm_hfhdpu
# Extracted data from post: B4wm_hfhdpu
# Extracting data from post: B4wm2Aahct9
# Extracted data from post: B4wm2Aahct9
# Extracting data from post: B4wmo3mBaIK
# Extracted data from post: B4wmo3mBaIK
# Extracting data from post: B4hpbeSBBW0
# Extracted data from post: B4hpbeSBBW0
# Extracting data from post: B4hpTyHBtyS
# Extracted data from post: B4hpTyHBtyS
# Extracting data from post: B4hpOsVB5nR
# Extracted data from post: B4hpOsVB5nR
# Extracting data from post: B4HjnF4hgI6
# Extracted data from post: B4HjnF4hgI6
# Extracting data from post: B4HjQUsBGhQ
# Extracted data from post: B4HjQUsBGhQ
# Extracting data from post: B4HjEz7Bn8z
# Extracted data from post: B4HjEz7Bn8z
# Extracting data from post: B3rcZ3ABKvA
# Extracted data from post: B3rcZ3ABKvA
# Extracting data from post: B3rcTVwh4kj
# Extracted data from post: B3rcTVwh4kj
# Extracting data from post: B3rbmIAhfpV
# Extracted data from post: B3rbmIAhfpV
# Extracting data from post: B3HD7tbBfyT
# Extracted data from post: B3HD7tbBfyT
# Extracting data from post: B3HD5qhhS4X
# Extracted data from post: B3HD5qhhS4X
# Extracting data from post: B3HDvJ8hqvS
# Extracted data from post: B3HDvJ8hqvS
# Extracting data from post: B2CIiTfB0fd
# Extracted data from post: B2CIiTfB0fd
# Extracting data from post: B2CIf62BiRX
# Extracted data from post: B2CIf62BiRX
# Extracting data from post: B2CIcrSBVny
# Extracted data from post: B2CIcrSBVny
# Extracting data from post: B1yRgeRh6j7
# Extracted data from post: B1yRgeRh6j7
# Extracting data from post: B1yRE7_hunM
# Extracted data from post: B1yRE7_hunM
# Extracting data from post: B1yQvauhJwz
# Extracted data from post: B1yQvauhJwz
# Extracting data from post: B1MLHWEBN7V
# Extracted data from post: B1MLHWEBN7V
# Extracting data from post: B1MLE1vBEN6
# Extracted data from post: B1MLE1vBEN6
# Extracting data from post: B1MLBoYBSXq
# Extracted data from post: B1MLBoYBSXq
# Extracting data from post: B0zjcHBBWFc
#
# Too many queries in the last time. Need to wait 19 seconds, until 14:17.
# Extracted data from post: B0zjcHBBWFc
# Extracting data from post: B0zhaUFhAqs
# Extracted data from post: B0zhaUFhAqs
# Extracting data from post: B0zg7yUh_eD
# Extracted data from post: B0zg7yUh_eD
# Extracting data from post: B0vgVodh2s-
# Extracted data from post: B0vgVodh2s-
# Extracting data from post: B0vde1mBwRR
# Extracted data from post: B0vde1mBwRR
# Extracting data from post: B0vczFtB4jE
# Extracted data from post: B0vczFtB4jE
# Extracting data from post: B0ta_Xsh3fv
# Extracted data from post: B0ta_Xsh3fv
# Extracting data from post: B0tZPythHOo
# Extracted data from post: B0tZPythHOo
# Extracting data from post: B0tM2aVAwD-
# Extracted data from post: B0tM2aVAwD-

# %%
# Save the data to a CSV file
with open('fampay_instagram_data_latest_all.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['shortcode', 'caption', 'upload_time', 'num_likes', 'num_comments', 'is_video', 'video_views', 'url']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for post_data in posts_data:
        writer.writerow(post_data)

print("FamPay Instagram data has been saved to fampay_instagram_data.csv.")
# Out:
# FamPay Instagram data has been saved to fampay_instagram_data.csv.
