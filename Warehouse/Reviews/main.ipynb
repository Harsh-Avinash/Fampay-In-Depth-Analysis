# %%
import csv
import time
from google_play_scraper import reviews

app_id = 'com.fampay.in'
lang = 'en'
country = 'in'

# %%
def count_csv(path):
    with open(path, 'r') as f:
        reader = csv.reader(f)
        return sum(1 for row in reader)

# %%
count_csv("app_reviews_5.csv")
# Out:
# 67958

# %%
types = [5]

# %%
for i in types:
    print(i,"star reviews")
    def get_reviews(app_id, lang, country, token=None):
        print("Fetching reviews for", app_id, "with token", token)
        result, continuation_token = reviews(
            app_id,
            lang=lang,
            country=country,
            count=1000,
            sort=2,  # Sort by most relevant
            filter_score_with=i,  # Filter one-star reviews
            continuation_token=token # type: ignore
        )
        return result, continuation_token

    # Fetch one-star reviews in batches and save them to a CSV file

    file_name = "app_reviews_"+str(i)+".csv"

    with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['reviewId', 'userName', 'userImage', 'content', 'score', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        
        token = None
        review_count = 0

        while review_count < 10000000:  # Change this to the desired number of reviews
            reviews_batch, token = get_reviews(app_id, lang, country, token)
            if not reviews_batch:
                break  # Break if there are no more reviews

            for review in reviews_batch:
                writer.writerow(review)
                review_count += 1

            print(review_count, "reviews fetched so far")
            # time.sleep(5)  # Sleep for 60 seconds between requests
            # print("I'm back")
# Out:
# 5 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163962FFEC0>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669B650>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696AED0>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696B3D0>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964EF2E0>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955A5C60>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964DBB00>
# 8000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394C97560>
# 9000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939D5080>
# 10000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955C6ED0>
# 11000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669BBF0>
# 12000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163954E62A0>
# 13000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639677C950>
# 14000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016396990130>
# 15000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696BF60>
# 16000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AB0130>
# 17000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955C76A0>
# 18000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AB01D0>
# 19000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955A5C60>
# 20000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394CFB790>
# 21000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939B26B0>
# 22000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964DBCE0>
# 23000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939F13F0>
# 24000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955C7650>
# 25000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC9FD0>
# 26000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696B8D0>
# 27000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394CFA2A0>
# 28000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395F2FC90>
# 29000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC9FD0>
# 30000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394CF94E0>
# 31000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016396990130>
# 32000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016396990450>
# 33000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163937A7F10>
# 34000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939D6A20>
# 35000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639677CB30>
# 36000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395F2FA60>
# 37000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955C7650>
# 38000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669BBF0>
# 39000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC8C20>
# 40000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964DB790>
# 41000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696B3D0>
# 42000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394C97560>
# 43000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163962FE250>
# 44000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395F2FA60>
# 45000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC8590>
# 46000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955A5C60>
# 47000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016396990450>
# 48000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163969900E0>
# 49000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955A5C60>
# 50000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163954E5940>
# 51000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696B3D0>
# 52000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163969900E0>
# 53000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964EE480>
# 54000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639573BFB0>
# 55000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939F0220>
# 56000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AB01D0>
# 57000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669B470>
# 58000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394AEC130>
# 59000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669B470>
# 60000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964EE480>
# 61000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939D6A20>
# 62000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939F09F0>
# 63000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163962FC4F0>
# 64000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163954E5940>
# 65000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394CFA390>
# 66000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669B470>
# 67000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639677C090>
# 68000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC8C20>
# 69000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639573BFB0>
# 70000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669B650>
# 71000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AB0130>
# 72000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394AEC130>
# 73000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939D4FE0>
# 74000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AB0130>
# 75000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939D6A20>
# 76000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163969900E0>
# 77000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939B29D0>
# 78000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639552C0E0>
# 79000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939B3E70>
# 80000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163954E5940>
# 81000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163955A5C60>
# 82000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC8C20>
# 83000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395F60E50>
# 84000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939B3150>
# 85000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC8C20>
# 86000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AB0130>
# 87000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163937A7F10>
# 88000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395AC8C20>
# 89000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163962FC4F0>
# 90000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696BCE0>
# 91000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639696AED0>
# 92000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939B1940>
# 93000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964EF2E0>
# 94000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163964EE480>
# 95000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639677C220>
# 96000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639677CB30>
# 97000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163954E62A0>
# 98000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394AEC130>
# 99000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x00000163939F0220>
# 100000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395F2FC90>
# 101000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001639669B470>
# 102000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394C97560>
# 103000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016395F605E0>
# 103802 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016394AEC130>
