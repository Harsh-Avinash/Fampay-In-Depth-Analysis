# %%
import csv
import time
from google_play_scraper import reviews
import pandas as pd

app_id = 'com.fampay.in'
lang = 'en'
country = 'in'

# %%
def count_csv(path):
    with open(path, 'r') as f:
        reader = csv.reader(f)
        return sum(1 for row in reader)

# %%
types = [1, 2, 3, 4, 5]

# %%
for i in types:
    print(i,"star reviews")
    def get_reviews(app_id, lang, country, token=None):
        print("Fetching reviews for", app_id, "with token", token)
        result, continuation_token = reviews(
            app_id,
            lang=lang,
            country=country,
            count=1000,
            sort=2,  # Sort by most relevant
            filter_score_with=i,  # Filter one-star reviews
            continuation_token=token # type: ignore
        )
        return result, continuation_token

    # Fetch one-star reviews in batches and save them to a CSV file

    file_name = "app_reviews_"+str(i)+".csv"

    with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['reviewId', 'userName', 'userImage', 'content', 'score', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        
        token = None
        review_count = 0

        while review_count < 10000000:  # Change this to the desired number of reviews
            reviews_batch, token = get_reviews(app_id, lang, country, token)
            if not reviews_batch:
                break  # Break if there are no more reviews

            for review in reviews_batch:
                writer.writerow(review)
                review_count += 1

            print(review_count, "reviews fetched so far")
            # time.sleep(5)  # Sleep for 60 seconds between requests
            # print("I'm back")
# Out:
# 1 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E226E0A4D0>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2238E2930>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22490A7A0>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224888EA0>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A30FE0>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248DA570>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A10130>
# 8000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A30AE0>
# 9000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2238E2930>
# 10000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E222278F90>
# 11000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2273FB920>
# 12000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2241F8E50>
# 13000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225298720>
# 14000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22067A110>
# 15000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A332E0>
# 16000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248912B0>
# 17000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22537A930>
# 18000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224AB0E50>
# 19000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E226F2C630>
# 20000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2249A7CE0>
# 21000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2222784F0>
# 22000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E223DF0F90>
# 23000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22537A930>
# 24000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22490A7A0>
# 25000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22529AE30>
# 26000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2249171A0>
# 27000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224903A60>
# 28000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224995E90>
# 29000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E223DF2520>
# 30000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22491FE70>
# 31000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248926B0>
# 32000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E226E0AA70>
# 33000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2238E2930>
# 34000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E226F2C4F0>
# 35000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22529AE30>
# 36000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22455F1A0>
# 37000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22228EC50>
# 38000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22537A930>
# 38525 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2278289F0>
# 2 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22455F420>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A971F0>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22210FB00>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E223C7EED0>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E226E09A80>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225298720>
# 6120 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2273FADE0>
# 3 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248912B0>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E222122CF0>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E223C7EED0>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E223B7EF20>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224888EA0>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E222278F90>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E226E0AA70>
# 7584 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225256E80>
# 4 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2222784F0>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2273FBBF0>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248DA570>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22228EC50>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2249C8180>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22067A110>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224AB0E50>
# 8000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2249F53A0>
# 9000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2249171A0>
# 10000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2222789A0>
# 11000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A332E0>
# 12000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E227127CE0>
# 13000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22210FB00>
# 13408 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2276EBC40>
# 5 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22067A110>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2222789A0>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248818A0>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A332E0>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A971F0>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2273FB1F0>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A10130>
# 8000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E227300810>
# 9000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22490A7A0>
# 10000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224AB0E50>
# 11000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22067A110>
# 12000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22228EC50>
# 13000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224995E90>
# 14000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225298720>
# 15000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248912B0>
# 16000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E226E09B70>
# 17000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2249F6E80>
# 18000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225298720>
# 19000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A96CA0>
# 20000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225300AE0>
# 21000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22491B970>
# 22000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22228EC50>
# 23000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22455F1A0>
# 24000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2248D83B0>
# 25000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224995990>
# 26000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224293150>
# 27000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A30AE0>
# 28000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225256F20>
# 29000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2205A24D0>
# 30000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225256F20>
# 31000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224293150>
# 32000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224AB0E50>
# 33000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2222789A0>
# 34000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224995E90>
# 35000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22498B330>
# 36000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22529AE30>
# 37000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224903A60>
# 38000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2273005E0>
# 39000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E22491B970>
# 40000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A96CA0>
# 41000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2249F7790>
# 42000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225300AE0>
# 43000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224913290>
# 44000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224882160>
# 45000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2205A24D0>
# 46000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E227127CE0>
# 47000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A30FE0>
# 48000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224995990>
# 49000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225379760>
# 50000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224889170>
# 51000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E2222784F0>
# 52000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E225257060>
# 53000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x000001E224A57E20>

# %%
data = pd.read_csv('../../Warehouse/Reviews/app_reviews_1.csv')

for i in range(2,6):
    data_t = pd.read_csv('../../Warehouse/Reviews/app_reviews_'+str(i)+'.csv')
    data = pd.concat([data, data_t], ignore_index=True)
    print("Merging",i,"star reviews")

filename = "app_reviews_merged.csv"
data.to_csv(filename, index=False)
# Out:
# Merging 2 star reviews
# Merging 3 star reviews
# Merging 4 star reviews
# Merging 5 star reviews
