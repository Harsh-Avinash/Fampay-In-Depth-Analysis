# %%
import csv
import time
from google_play_scraper import reviews
import pandas as pd

app_id = 'com.fampay.in'
lang = 'en'
country = 'in'

# %%
def count_csv(path):
    with open(path, 'r') as f:
        reader = csv.reader(f)
        return sum(1 for row in reader)

# %%
types = [1, 2, 3, 4, 5]

# %%
for i in types:
    print(i,"star reviews")
    def get_reviews(app_id, lang, country, token=None):
        print("Fetching reviews for", app_id, "with token", token)
        result, continuation_token = reviews(
            app_id,
            lang=lang,
            country=country,
            count=1000,
            sort=2,  # Sort by most relevant
            filter_score_with=i,  # Filter one-star reviews
            continuation_token=token # type: ignore
        )
        return result, continuation_token

    # Fetch one-star reviews in batches and save them to a CSV file

    file_name = "app_reviews_"+str(i)+".csv"

    with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['reviewId', 'userName', 'userImage', 'content', 'score', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        
        token = None
        review_count = 0

        while review_count < 10000000:  # Change this to the desired number of reviews
            reviews_batch, token = get_reviews(app_id, lang, country, token)
            if not reviews_batch:
                break  # Break if there are no more reviews

            for review in reviews_batch:
                writer.writerow(review)
                review_count += 1

            print(review_count, "reviews fetched so far")
            # time.sleep(5)  # Sleep for 60 seconds between requests
            # print("I'm back")
# Out:
# 1 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79A80>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C793F0>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9396A520>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934AEBB0>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79710>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79710>
# 8000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934AEBB0>
# 9000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 10000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9346B510>
# 11000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 12000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AE2F0>
# 13000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934AEBB0>
# 14000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9396A520>
# 15000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79A80>
# 16000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 17000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934AEBB0>
# 18000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AE020>
# 19000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 20000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C793F0>
# 21000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 22000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 23000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 24000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 25000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AD90>
# 26000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 27000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 28000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AD90>
# 29000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 30000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79710>
# 31000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934AEBB0>
# 32000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 33000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 34000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9396A520>
# 35000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 36000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 37000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9346B510>
# 38000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AD90>
# 39000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E940A6AC0>
# 39246 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AE30>
# 2 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9443EE30>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AE30>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934971F0>
# 6219 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 3 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79080>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AFC0>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AD90>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79710>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79080>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934971F0>
# 7703 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AFA60>
# 4 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943ADC60>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AF240>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9396A520>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AE110>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9396A520>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934971F0>
# 8000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 9000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AEBB0>
# 10000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AFC0>
# 11000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E934971F0>
# 12000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AF790>
# 13000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79710>
# 13633 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 5 star reviews
# Fetching reviews for com.fampay.in with token None
# 1000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 2000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 3000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79080>
# 4000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 5000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 6000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 7000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 8000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 9000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 10000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943ADE90>
# 11000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79CB0>
# 12000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 13000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 14000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 15000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AE30>
# 16000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 17000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 18000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 19000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AFC0>
# 20000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 21000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 22000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 23000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 24000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8B600>
# 25000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 26000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8B600>
# 27000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E940A6AC0>
# 28000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AF1A0>
# 29000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79CB0>
# 30000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AE30>
# 31000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 32000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 33000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 34000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 35000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C793F0>
# 36000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 37000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AFC0>
# 38000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79CB0>
# 39000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AE30>
# 40000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79080>
# 41000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79A80>
# 42000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AE30>
# 43000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 44000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 45000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79CB0>
# 46000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 47000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8B600>
# 48000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 49000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 50000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 51000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 52000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 53000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8B600>
# 54000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 55000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AFE70>
# 56000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C7BD80>
# 57000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 58000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C793F0>
# 59000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 60000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C7BD80>
# 61000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9441F100>
# 62000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C793F0>
# 63000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 64000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 65000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 66000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9443D210>
# 67000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 68000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9443E2A0>
# 69000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9441E430>
# 70000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79080>
# 71000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C7BD80>
# 72000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79C60>
# 73000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E940A6AC0>
# 74000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79CB0>
# 75000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8B600>
# 76000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C7BD80>
# 77000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79080>
# 78000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C7BD80>
# 79000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 80000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 81000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E5FB00>
# 82000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E940A6AC0>
# 83000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 84000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 85000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E938A0C70>
# 86000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 87000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C7BD80>
# 88000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 89000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 90000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 91000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C796C0>
# 92000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AFC0>
# 93000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 94000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AFC0>
# 95000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943AFB50>
# 96000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E94671210>
# 97000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91D5C2C0>
# 98000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79350>
# 99000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C7BD80>
# 100000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79A80>
# 101000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E940A6AC0>
# 102000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79CB0>
# 103000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91C79580>
# 104000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E91E8AFC0>
# 105000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9443CB30>
# 106000 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E943771A0>
# 106541 reviews fetched so far
# Fetching reviews for com.fampay.in with token <google_play_scraper.features.reviews._ContinuationToken object at 0x0000016E9467AA70>

# %%
data = pd.read_csv('../../Warehouse/Reviews/app_reviews_1.csv')

for i in range(2,6):
    data_t = pd.read_csv('../../Warehouse/Reviews/app_reviews_'+str(i)+'.csv')
    data = pd.concat([data, data_t], ignore_index=True)
    print("Merging",i,"star reviews")

filename = "app_reviews_merged.csv"
data.to_csv(filename, index=False)
# Out:
# Merging 2 star reviews
# Merging 3 star reviews
# Merging 4 star reviews
# Merging 5 star reviews
